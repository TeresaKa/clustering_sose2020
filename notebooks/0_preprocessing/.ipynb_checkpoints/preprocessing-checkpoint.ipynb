# %% [markdown]
# **Notebook beinhaltet**:
# preprocessing des Datensatzes:
# + entferne Satzzeichen, "chorus", nur Kleinbuchstaben
# + füge Spalte mit Songlänge/ Anzahl der Token hinzu
# + erstelle ein Sample aus 25% des Originaldatensatzes
# + Stemming der Songtexte

# %%
import pandas as pd
import numpy as np
from collections import Counter

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# load raw data

# %%
songs = pd.read_csv("songs_plus_dates.csv")
songs
# Out:
#        Unnamed: 0                  song  date   artist  Unnamed: 0.1  \
# 0               0      Andante, Andante  1980     ABBA             1
# 1               2        As Good As New  1979     ABBA             2
# 2               4      Bang-A-Boomerang  1975     ABBA             4
# 3               7             Cassandra  1981     ABBA             6
# 4               8            Chiquitita  1979     ABBA             7
# ...           ...                   ...   ...      ...           ...
# 24438       66122        Breakin Dishes  2008  Rihanna         50861
# 24439       66128      Get It Over With  2012  Rihanna         50867
# 24440       66135            Half Of Me  2012  Rihanna         50869
# 24441       66137  Hate That I Love You  2008  Rihanna         50873
# 24442       66140                Higher  2016  Rihanna         50874
#
#                                                 link  \
# 0              /a/abba/andante+andante_20002708.html
# 1               /a/abba/as+good+as+new_20003033.html
# 2             /a/abba/bang+a+boomerang_20002668.html
# 3                    /a/abba/cassandra_20002811.html
# 4                   /a/abba/chiquitita_20002978.html
# ...                                              ...
# 24438        /r/rihanna/breakin+dishes_20421653.html
# 24439      /r/rihanna/get+it+over+with_21050292.html
# 24440            /r/rihanna/half+of+me_21050289.html
# 24441  /r/rihanna/hate+that+i+love+you_20417853.html
# 24442                /r/rihanna/higher_21096406.html
#
#                                                     text Genre1    Genre2
# 0      Take it easy with me, please  \nTouch me gentl...    Pop      Rock
# 1      I'll never know why I had to go  \nWhy I had t...    Pop      Rock
# 2      Making somebody happy is a question of give an...    Pop      Rock
# 3      Down in the street they're all singing and sho...    Pop      Rock
# 4      Chiquitita, tell me what's wrong  \nYou're enc...    Pop      Rock
# ...                                                  ...    ...       ...
# 24438  I don't know who you think I am  \nI don't kno...    Pop   Hip Hop
# 24439  It's dark in the day, now say, now don't compl...    Pop   Hip Hop
# 24440  You saw me on the television, setting fire to ...    Pop   Hip Hop
# 24441  That's how much I love you  \nThat's how much ...    Pop   Hip Hop
# 24442  [Verse]  \nThis whiskey got me feelin' pretty ...    Pop   Hip Hop
#
# [24443 rows x 9 columns]

# %%
songs.drop('Unnamed: 0', axis=1, inplace=True)
songs.drop('Unnamed: 0.1', axis=1, inplace=True)
songs
# Out:
#                        song  date   artist  \
# 0          Andante, Andante  1980     ABBA
# 1            As Good As New  1979     ABBA
# 2          Bang-A-Boomerang  1975     ABBA
# 3                 Cassandra  1981     ABBA
# 4                Chiquitita  1979     ABBA
# ...                     ...   ...      ...
# 24438        Breakin Dishes  2008  Rihanna
# 24439      Get It Over With  2012  Rihanna
# 24440            Half Of Me  2012  Rihanna
# 24441  Hate That I Love You  2008  Rihanna
# 24442                Higher  2016  Rihanna
#
#                                                 link  \
# 0              /a/abba/andante+andante_20002708.html
# 1               /a/abba/as+good+as+new_20003033.html
# 2             /a/abba/bang+a+boomerang_20002668.html
# 3                    /a/abba/cassandra_20002811.html
# 4                   /a/abba/chiquitita_20002978.html
# ...                                              ...
# 24438        /r/rihanna/breakin+dishes_20421653.html
# 24439      /r/rihanna/get+it+over+with_21050292.html
# 24440            /r/rihanna/half+of+me_21050289.html
# 24441  /r/rihanna/hate+that+i+love+you_20417853.html
# 24442                /r/rihanna/higher_21096406.html
#
#                                                     text Genre1    Genre2
# 0      Take it easy with me, please  \nTouch me gentl...    Pop      Rock
# 1      I'll never know why I had to go  \nWhy I had t...    Pop      Rock
# 2      Making somebody happy is a question of give an...    Pop      Rock
# 3      Down in the street they're all singing and sho...    Pop      Rock
# 4      Chiquitita, tell me what's wrong  \nYou're enc...    Pop      Rock
# ...                                                  ...    ...       ...
# 24438  I don't know who you think I am  \nI don't kno...    Pop   Hip Hop
# 24439  It's dark in the day, now say, now don't compl...    Pop   Hip Hop
# 24440  You saw me on the television, setting fire to ...    Pop   Hip Hop
# 24441  That's how much I love you  \nThat's how much ...    Pop   Hip Hop
# 24442  [Verse]  \nThis whiskey got me feelin' pretty ...    Pop   Hip Hop
#
# [24443 rows x 7 columns]

# %%
for i, row in songs.iterrows():
    songs.at[i, 'text'] = row.text.replace(',',' ').replace('(',' ').replace(')',' ').replace('\n', '').replace("[Chorus]", "").lower().split()
songs
# Out:
#                        song  date   artist  \
# 0          Andante, Andante  1980     ABBA
# 1            As Good As New  1979     ABBA
# 2          Bang-A-Boomerang  1975     ABBA
# 3                 Cassandra  1981     ABBA
# 4                Chiquitita  1979     ABBA
# ...                     ...   ...      ...
# 24438        Breakin Dishes  2008  Rihanna
# 24439      Get It Over With  2012  Rihanna
# 24440            Half Of Me  2012  Rihanna
# 24441  Hate That I Love You  2008  Rihanna
# 24442                Higher  2016  Rihanna
#
#                                                 link  \
# 0              /a/abba/andante+andante_20002708.html
# 1               /a/abba/as+good+as+new_20003033.html
# 2             /a/abba/bang+a+boomerang_20002668.html
# 3                    /a/abba/cassandra_20002811.html
# 4                   /a/abba/chiquitita_20002978.html
# ...                                              ...
# 24438        /r/rihanna/breakin+dishes_20421653.html
# 24439      /r/rihanna/get+it+over+with_21050292.html
# 24440            /r/rihanna/half+of+me_21050289.html
# 24441  /r/rihanna/hate+that+i+love+you_20417853.html
# 24442                /r/rihanna/higher_21096406.html
#
#                                                     text Genre1    Genre2
# 0      take it easy with me  please  touch me gently ...    Pop      Rock
# 1      i'll never know why i had to go  why i had to ...    Pop      Rock
# 2      making somebody happy is a question of give an...    Pop      Rock
# 3      down in the street they're all singing and sho...    Pop      Rock
# 4      chiquitita  tell me what's wrong  you're encha...    Pop      Rock
# ...                                                  ...    ...       ...
# 24438  i don't know who you think i am  i don't know ...    Pop   Hip Hop
# 24439  it's dark in the day  now say  now don't compl...    Pop   Hip Hop
# 24440  you saw me on the television  setting fire to ...    Pop   Hip Hop
# 24441  that's how much i love you  that's how much i ...    Pop   Hip Hop
# 24442  [verse]  this whiskey got me feelin' pretty  s...    Pop   Hip Hop
#
# [24443 rows x 7 columns]

# %%
songs.to_csv("songs_plus_dates.csv")

# %% [markdown]
# remove artists with less than 60 songs

# %%
c = Counter(songs.artist)

# %%
for v, k in c.items():
    if k<60:
        songs = songs[songs.artist!=v]

# %%
songs['number_of_tokens'] = songs.text.str.len()

# %%
# songs.drop('link', axis=1, inplace=True)
songs
# Out:
#                        song  date   artist  \
# 0          Andante, Andante  1980     ABBA
# 1            As Good As New  1979     ABBA
# 2          Bang-A-Boomerang  1975     ABBA
# 3                 Cassandra  1981     ABBA
# 4                Chiquitita  1979     ABBA
# ...                     ...   ...      ...
# 24438        Breakin Dishes  2008  Rihanna
# 24439      Get It Over With  2012  Rihanna
# 24440            Half Of Me  2012  Rihanna
# 24441  Hate That I Love You  2008  Rihanna
# 24442                Higher  2016  Rihanna
#
#                                                 link  \
# 0              /a/abba/andante+andante_20002708.html
# 1               /a/abba/as+good+as+new_20003033.html
# 2             /a/abba/bang+a+boomerang_20002668.html
# 3                    /a/abba/cassandra_20002811.html
# 4                   /a/abba/chiquitita_20002978.html
# ...                                              ...
# 24438        /r/rihanna/breakin+dishes_20421653.html
# 24439      /r/rihanna/get+it+over+with_21050292.html
# 24440            /r/rihanna/half+of+me_21050289.html
# 24441  /r/rihanna/hate+that+i+love+you_20417853.html
# 24442                /r/rihanna/higher_21096406.html
#
#                                                     text Genre1    Genre2  \
# 0      take it easy with me  please  touch me gently ...    Pop      Rock
# 1      i'll never know why i had to go  why i had to ...    Pop      Rock
# 2      making somebody happy is a question of give an...    Pop      Rock
# 3      down in the street they're all singing and sho...    Pop      Rock
# 4      chiquitita  tell me what's wrong  you're encha...    Pop      Rock
# ...                                                  ...    ...       ...
# 24438  i don't know who you think i am  i don't know ...    Pop   Hip Hop
# 24439  it's dark in the day  now say  now don't compl...    Pop   Hip Hop
# 24440  you saw me on the television  setting fire to ...    Pop   Hip Hop
# 24441  that's how much i love you  that's how much i ...    Pop   Hip Hop
# 24442  [verse]  this whiskey got me feelin' pretty  s...    Pop   Hip Hop
#
#        number_of_tokens
# 0                  1381
# 1                  1438
# 2                  1223
# 3                  1964
# 4                  1546
# ...                 ...
# 24438              1966
# 24439              1721
# 24440              1315
# 24441              1922
# 24442               604
#
# [24443 rows x 8 columns]

# %%
songs.to_csv("songs_plus_dates.csv")

# %% [markdown]
# #### sample data

# %%
songs_sample = songs.copy()
songs_sample = songs_sample.sample(frac=.25, replace=False, random_state=42)
songs_sample
# Out:
#                    artist                          song  \
# 20468           Van Halen        Take Your Whiskey Home
# 41605           Lil Wayne                     Army Gunz
# 52292       Stevie Wonder              Isn't She Lovely
# 42697        Mariah Carey                  O Holy Night
# 27993               Clash  I'm So Bored With The U.S.A.
# ...                   ...                           ...
# 25325      Billie Holiday                My Last Affair
# 28783  Dave Matthews Band             The Space Between
# 18645             Squeeze            Crying In My Sleep
# 32684        Foo Fighters                    Dear Lover
# 9201           Jason Mraz              Kickin' With You
#
#                                                     text  number_of_tokens
# 20468  [well, my, baby, she, don't, want, me, around....               224
# 41605  [yeah, yeah, yeah, (i, got, army, gunz), yeah,...               578
# 52292  [isn't, she, lovely, isn't, she, wonderful, is...               108
# 42697  [o, holy, night, the, stars, are, brightly, sh...                78
# 27993  [yankee, soldier, he, want, to, shoot, some, s...               113
# ...                                                  ...               ...
# 25325  [can't, you, see, what, love, and, romance, ha...                97
# 28783  [you, cannot, quit, me, so, quickly, is, no, h...               310
# 18645  [breaking, up, is, breaking, my, heart, is, sh...               178
# 32684  [dear, lover, do, you, remember?, the, sound, ...               134
# 9201   [ahhhh, oh, kickin', with, you, wooh, huh, yea...               311
#
# [12708 rows x 4 columns]

# %%
songs_sample.to_csv("sample_25percent.csv")

# %% [markdown]
# ### Stemming

# %%
songs = pd.read_csv("songs_plus_dates.csv")
songs.head(2)
# Out:
#    Unnamed: 0              song  date artist  \
# 0           0  Andante, Andante  1980   ABBA
# 1           1    As Good As New  1979   ABBA
#
#                                     link  \
# 0  /a/abba/andante+andante_20002708.html
# 1   /a/abba/as+good+as+new_20003033.html
#
#                                                 text Genre1 Genre2  \
# 0  take it easy with me  please  touch me gently ...    Pop   Rock
# 1  i'll never know why i had to go  why i had to ...    Pop   Rock
#
#    number_of_tokens
# 0              1381
# 1              1438

# %%
import spacy
import en_core_web_sm
from nltk.stem import PorterStemmer
from nltk.stem import SnowballStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

sentence = songs.text[0]

ps = PorterStemmer()

for i, row in songs.iterrows():
    words = word_tokenize(row.text)
    sent = ""
    for word in words:
        sent = sent + " " + ps.stem(word)
    songs.at[i,"stemmed_text"] = sent
songs
# Out:
#        Unnamed: 0                  song  date   artist  \
# 0               0      Andante, Andante  1980     ABBA
# 1               1        As Good As New  1979     ABBA
# 2               2      Bang-A-Boomerang  1975     ABBA
# 3               3             Cassandra  1981     ABBA
# 4               4            Chiquitita  1979     ABBA
# ...           ...                   ...   ...      ...
# 24438       24438        Breakin Dishes  2008  Rihanna
# 24439       24439      Get It Over With  2012  Rihanna
# 24440       24440            Half Of Me  2012  Rihanna
# 24441       24441  Hate That I Love You  2008  Rihanna
# 24442       24442                Higher  2016  Rihanna
#
#                                                 link  \
# 0              /a/abba/andante+andante_20002708.html
# 1               /a/abba/as+good+as+new_20003033.html
# 2             /a/abba/bang+a+boomerang_20002668.html
# 3                    /a/abba/cassandra_20002811.html
# 4                   /a/abba/chiquitita_20002978.html
# ...                                              ...
# 24438        /r/rihanna/breakin+dishes_20421653.html
# 24439      /r/rihanna/get+it+over+with_21050292.html
# 24440            /r/rihanna/half+of+me_21050289.html
# 24441  /r/rihanna/hate+that+i+love+you_20417853.html
# 24442                /r/rihanna/higher_21096406.html
#
#                                                     text Genre1    Genre2  \
# 0      take it easy with me  please  touch me gently ...    Pop      Rock
# 1      i'll never know why i had to go  why i had to ...    Pop      Rock
# 2      making somebody happy is a question of give an...    Pop      Rock
# 3      down in the street they're all singing and sho...    Pop      Rock
# 4      chiquitita  tell me what's wrong  you're encha...    Pop      Rock
# ...                                                  ...    ...       ...
# 24438  i don't know who you think i am  i don't know ...    Pop   Hip Hop
# 24439  it's dark in the day  now say  now don't compl...    Pop   Hip Hop
# 24440  you saw me on the television  setting fire to ...    Pop   Hip Hop
# 24441  that's how much i love you  that's how much i ...    Pop   Hip Hop
# 24442  [verse]  this whiskey got me feelin' pretty  s...    Pop   Hip Hop
#
#        number_of_tokens                                       stemmed_text
# 0                  1381   take it easi with me pleas touch me gentli li...
# 1                  1438   i 'll never know whi i had to go whi i had to...
# 2                  1223   make somebodi happi is a question of give and...
# 3                  1964   down in the street they 're all sing and shou...
# 4                  1546   chiquitita tell me what 's wrong you 're ench...
# ...                 ...                                                ...
# 24438              1966   i do n't know who you think i am i do n't kno...
# 24439              1721   it 's dark in the day now say now do n't comp...
# 24440              1315   you saw me on the televis set fire to all the...
# 24441              1922   that 's how much i love you that 's how much ...
# 24442               604   [ vers ] thi whiskey got me feelin ' pretti s...
#
# [24443 rows x 10 columns]

# %%
songs.drop("Unnamed: 0", axis=1, inplace=True)

# %%
songs.to_csv("songs_plus_dates.csv")

# %%
s = pd.read_csv("../../songs_plus_dates.csv")
s
# Out:
#        Unnamed: 0                  song  date   artist  \
# 0               0      Andante, Andante  1980     ABBA
# 1               1        As Good As New  1979     ABBA
# 2               2      Bang-A-Boomerang  1975     ABBA
# 3               3             Cassandra  1981     ABBA
# 4               4            Chiquitita  1979     ABBA
# ...           ...                   ...   ...      ...
# 24438       24438        Breakin Dishes  2008  Rihanna
# 24439       24439      Get It Over With  2012  Rihanna
# 24440       24440            Half Of Me  2012  Rihanna
# 24441       24441  Hate That I Love You  2008  Rihanna
# 24442       24442                Higher  2016  Rihanna
#
#                                                 link  \
# 0              /a/abba/andante+andante_20002708.html
# 1               /a/abba/as+good+as+new_20003033.html
# 2             /a/abba/bang+a+boomerang_20002668.html
# 3                    /a/abba/cassandra_20002811.html
# 4                   /a/abba/chiquitita_20002978.html
# ...                                              ...
# 24438        /r/rihanna/breakin+dishes_20421653.html
# 24439      /r/rihanna/get+it+over+with_21050292.html
# 24440            /r/rihanna/half+of+me_21050289.html
# 24441  /r/rihanna/hate+that+i+love+you_20417853.html
# 24442                /r/rihanna/higher_21096406.html
#
#                                                     text Genre1    Genre2  \
# 0      take it easy with me  please  touch me gently ...    Pop      Rock
# 1      i'll never know why i had to go  why i had to ...    Pop      Rock
# 2      making somebody happy is a question of give an...    Pop      Rock
# 3      down in the street they're all singing and sho...    Pop      Rock
# 4      chiquitita  tell me what's wrong  you're encha...    Pop      Rock
# ...                                                  ...    ...       ...
# 24438  i don't know who you think i am  i don't know ...    Pop   Hip Hop
# 24439  it's dark in the day  now say  now don't compl...    Pop   Hip Hop
# 24440  you saw me on the television  setting fire to ...    Pop   Hip Hop
# 24441  that's how much i love you  that's how much i ...    Pop   Hip Hop
# 24442  [verse]  this whiskey got me feelin' pretty  s...    Pop   Hip Hop
#
#        number_of_tokens                                       stemmed_text  \
# 0                  1381   take it easi with me pleas touch me gentli li...
# 1                  1438   i 'll never know whi i had to go whi i had to...
# 2                  1223   make somebodi happi is a question of give and...
# 3                  1964   down in the street they 're all sing and shou...
# 4                  1546   chiquitita tell me what 's wrong you 're ench...
# ...                 ...                                                ...
# 24438              1966   i do n't know who you think i am i do n't kno...
# 24439              1721   it 's dark in the day now say now do n't comp...
# 24440              1315   you saw me on the televis set fire to all the...
# 24441              1922   that 's how much i love you that 's how much ...
# 24442               604   [ vers ] thi whiskey got me feelin ' pretti s...
#
#                                                      POS
# 0      easy slow andante soft light andante strong st...
# 1      lousy rotten tough enough good new good new ne...
# 2      happy little sweet sweet tender dumb dumb dumb...
# 3      alive dead hollow smart sorry last sorry final...
# 4      wrong own sad quiet sure new new hard sad quie...
# ...                                                  ...
# 24438  cool hot restless fool baby lil bit flame nigh...
# 24439  dark afraid dry afraid high high high high hig...
# 24440  dirty own beautiful crazy television fire idea...
# 24441  much upset mad wrong much only sad fair right ...
# 24442  impolite sorry other creative poetic only old ...
#
# [24443 rows x 11 columns]

# %%
for i, row in s.iterrows():
    s.at[i, 'text'] = row.text.replace('[',' ').replace('chorus',' ').lower()
s
# Out:
#        Unnamed: 0                  song  date   artist  \
# 0               0      Andante, Andante  1980     ABBA
# 1               1        As Good As New  1979     ABBA
# 2               2      Bang-A-Boomerang  1975     ABBA
# 3               3             Cassandra  1981     ABBA
# 4               4            Chiquitita  1979     ABBA
# ...           ...                   ...   ...      ...
# 24438       24438        Breakin Dishes  2008  Rihanna
# 24439       24439      Get It Over With  2012  Rihanna
# 24440       24440            Half Of Me  2012  Rihanna
# 24441       24441  Hate That I Love You  2008  Rihanna
# 24442       24442                Higher  2016  Rihanna
#
#                                                 link  \
# 0              /a/abba/andante+andante_20002708.html
# 1               /a/abba/as+good+as+new_20003033.html
# 2             /a/abba/bang+a+boomerang_20002668.html
# 3                    /a/abba/cassandra_20002811.html
# 4                   /a/abba/chiquitita_20002978.html
# ...                                              ...
# 24438        /r/rihanna/breakin+dishes_20421653.html
# 24439      /r/rihanna/get+it+over+with_21050292.html
# 24440            /r/rihanna/half+of+me_21050289.html
# 24441  /r/rihanna/hate+that+i+love+you_20417853.html
# 24442                /r/rihanna/higher_21096406.html
#
#                                                     text Genre1    Genre2  \
# 0      take it easy with me  please  touch me gently ...    Pop      Rock
# 1      i'll never know why i had to go  why i had to ...    Pop      Rock
# 2      making somebody happy is a question of give an...    Pop      Rock
# 3      down in the street they're all singing and sho...    Pop      Rock
# 4      chiquitita  tell me what's wrong  you're encha...    Pop      Rock
# ...                                                  ...    ...       ...
# 24438  i don't know who you think i am  i don't know ...    Pop   Hip Hop
# 24439  it's dark in the day  now say  now don't compl...    Pop   Hip Hop
# 24440  you saw me on the television  setting fire to ...    Pop   Hip Hop
# 24441  that's how much i love you  that's how much i ...    Pop   Hip Hop
# 24442       this whiskey got me feelin' pretty  so pa...    Pop   Hip Hop
#
#        number_of_tokens                                       stemmed_text  \
# 0                  1381   take it easi with me pleas touch me gentli li...
# 1                  1438   i 'll never know whi i had to go whi i had to...
# 2                  1223   make somebodi happi is a question of give and...
# 3                  1964   down in the street they 're all sing and shou...
# 4                  1546   chiquitita tell me what 's wrong you 're ench...
# ...                 ...                                                ...
# 24438              1966   i do n't know who you think i am i do n't kno...
# 24439              1721   it 's dark in the day now say now do n't comp...
# 24440              1315   you saw me on the televis set fire to all the...
# 24441              1922   that 's how much i love you that 's how much ...
# 24442               604   [ vers ] thi whiskey got me feelin ' pretti s...
#
#                                                      POS
# 0      easy slow andante soft light andante strong st...
# 1      lousy rotten tough enough good new good new ne...
# 2      happy little sweet sweet tender dumb dumb dumb...
# 3      alive dead hollow smart sorry last sorry final...
# 4      wrong own sad quiet sure new new hard sad quie...
# ...                                                  ...
# 24438  cool hot restless fool baby lil bit flame nigh...
# 24439  dark afraid dry afraid high high high high hig...
# 24440  dirty own beautiful crazy television fire idea...
# 24441  much upset mad wrong much only sad fair right ...
# 24442  impolite sorry other creative poetic only old ...
#
# [24443 rows x 11 columns]

# %%
s['decades'] = '0'
s.head(2)
# Out:
#    Unnamed: 0              song  date artist  \
# 0           0  Andante, Andante  1980   ABBA
# 1           1    As Good As New  1979   ABBA
#
#                                     link  \
# 0  /a/abba/andante+andante_20002708.html
# 1   /a/abba/as+good+as+new_20003033.html
#
#                                                 text Genre1 Genre2  \
# 0  take it easy with me  please  touch me gently ...    Pop   Rock
# 1  i'll never know why i had to go  why i had to ...    Pop   Rock
#
#    number_of_tokens                                       stemmed_text  \
# 0              1381   take it easi with me pleas touch me gentli li...
# 1              1438   i 'll never know whi i had to go whi i had to...
#
#                                                  POS decades
# 0  easy slow andante soft light andante strong st...       0
# 1  lousy rotten tough enough good new good new ne...       0

# %%
for i, row in s.iterrows():
    if row.date >=1930 and row.date < 1940:
        s.at[i, 'decades'] = '1930s'
    if row.date >=1940 and row.date < 1950:
        s.at[i, 'decades'] = '1940s'
    if row.date >=1950 and row.date < 1960:
        s.at[i, 'decades'] = '1950s'
    if row.date >=1960 and row.date < 1970:
        s.at[i, 'decades'] = '1960s'
    if row.date >=1970 and row.date < 1980:
        s.at[i, 'decades'] = '1970s'
    if row.date >=1980 and row.date < 1990:
        s.at[i, 'decades'] = '1980s'
    if row.date >=1990 and row.date < 2000:
        s.at[i, 'decades'] = '1990s'
    if row.date >=2000 and row.date < 2010:
        s.at[i, 'decades'] = '2000s'
    if row.date >=2010 and row.date < 2020:
        s.at[i, 'decades'] = '2010s'
    if row.date >=2020:
        s.at[i, 'decades'] = '2020s'

# %%
s
# Out:
#        Unnamed: 0                  song  date   artist  \
# 0               0      Andante, Andante  1980     ABBA
# 1               1        As Good As New  1979     ABBA
# 2               2      Bang-A-Boomerang  1975     ABBA
# 3               3             Cassandra  1981     ABBA
# 4               4            Chiquitita  1979     ABBA
# ...           ...                   ...   ...      ...
# 24438       24438        Breakin Dishes  2008  Rihanna
# 24439       24439      Get It Over With  2012  Rihanna
# 24440       24440            Half Of Me  2012  Rihanna
# 24441       24441  Hate That I Love You  2008  Rihanna
# 24442       24442                Higher  2016  Rihanna
#
#                                                 link  \
# 0              /a/abba/andante+andante_20002708.html
# 1               /a/abba/as+good+as+new_20003033.html
# 2             /a/abba/bang+a+boomerang_20002668.html
# 3                    /a/abba/cassandra_20002811.html
# 4                   /a/abba/chiquitita_20002978.html
# ...                                              ...
# 24438        /r/rihanna/breakin+dishes_20421653.html
# 24439      /r/rihanna/get+it+over+with_21050292.html
# 24440            /r/rihanna/half+of+me_21050289.html
# 24441  /r/rihanna/hate+that+i+love+you_20417853.html
# 24442                /r/rihanna/higher_21096406.html
#
#                                                     text Genre1    Genre2  \
# 0      take it easy with me  please  touch me gently ...    Pop      Rock
# 1      i'll never know why i had to go  why i had to ...    Pop      Rock
# 2      making somebody happy is a question of give an...    Pop      Rock
# 3      down in the street they're all singing and sho...    Pop      Rock
# 4      chiquitita  tell me what's wrong  you're encha...    Pop      Rock
# ...                                                  ...    ...       ...
# 24438  i don't know who you think i am  i don't know ...    Pop   Hip Hop
# 24439  it's dark in the day  now say  now don't compl...    Pop   Hip Hop
# 24440  you saw me on the television  setting fire to ...    Pop   Hip Hop
# 24441  that's how much i love you  that's how much i ...    Pop   Hip Hop
# 24442       this whiskey got me feelin' pretty  so pa...    Pop   Hip Hop
#
#        number_of_tokens                                       stemmed_text  \
# 0                  1381   take it easi with me pleas touch me gentli li...
# 1                  1438   i 'll never know whi i had to go whi i had to...
# 2                  1223   make somebodi happi is a question of give and...
# 3                  1964   down in the street they 're all sing and shou...
# 4                  1546   chiquitita tell me what 's wrong you 're ench...
# ...                 ...                                                ...
# 24438              1966   i do n't know who you think i am i do n't kno...
# 24439              1721   it 's dark in the day now say now do n't comp...
# 24440              1315   you saw me on the televis set fire to all the...
# 24441              1922   that 's how much i love you that 's how much ...
# 24442               604   [ vers ] thi whiskey got me feelin ' pretti s...
#
#                                                      POS decades
# 0      easy slow andante soft light andante strong st...   1980s
# 1      lousy rotten tough enough good new good new ne...   1970s
# 2      happy little sweet sweet tender dumb dumb dumb...   1970s
# 3      alive dead hollow smart sorry last sorry final...   1980s
# 4      wrong own sad quiet sure new new hard sad quie...   1970s
# ...                                                  ...     ...
# 24438  cool hot restless fool baby lil bit flame nigh...   2000s
# 24439  dark afraid dry afraid high high high high hig...   2010s
# 24440  dirty own beautiful crazy television fire idea...   2010s
# 24441  much upset mad wrong much only sad fair right ...   2000s
# 24442  impolite sorry other creative poetic only old ...   2010s
#
# [24443 rows x 12 columns]

# %%
s.to_csv("../../songs_plus_dates.csv")
