# %% [markdown]
# ## Datensatz verkleinern

# %% [markdown]
# **Notebook beinhaltet**:
# + Datensatzverkleinerung nach Anzahl der Songs
# + Visualisierungen des verkleinerten Datensatzes

# %% [markdown]
# ### 100 Songs pro Band

# %%
import pandas as pd 
import numpy as np
from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
# %matplotlib inline

# %%
df = pd.read_csv("../songtexte_bereinigt_gekuerzt.csv")
c = Counter(df.artist)
for v, k in c.items():
    if k<=99:
        df = df[df.artist!=v]

# %%
g = df.groupby('artist')
df2 = pd.DataFrame(g.apply(lambda x: x.sample(g.size().min())))

# %%
df2 = df2.rename(columns={'artist': 'artists'})

# %%
df2

# %%
df2.to_csv("songs_100.csv")

# %% [markdown]
# ### 25 Songs pro Band

# %%
df = pd.read_csv("songs_100.csv")

# %%
g = df.groupby('artists')
df3 = pd.DataFrame(g.apply(lambda group: group.iloc[75:, 75:]))

# %%
df3.to_csv("songs_25.csv")
df3 = pd.read_csv("songs_25.csv")

# %%
df3.set_index('Unnamed: 1', inplace = True)
df3['check'] = 'True'

# %%
frames = [df, df3]
result = pd.concat(frames, axis=1)

# %%
#alle rows, die NAN in der Spalte check sind, löschen
result.dropna(subset = ["check"], inplace=True)

# %%
result.to_csv("songs_25.csv")

# %%
df = pd.read_csv("../songs_25.csv")

# %%
del df['Unnamed: 0']

# %%
df
# Out:
#      artists                song  \
# 0       ABBA            Me And I
# 1       ABBA        My Mama Said
# 2       ABBA   Hole In Your Soul
# 3       ABBA           Cassandra
# 4       ABBA       Just A Notion
# ...      ...                 ...
# 6795  ZZ Top            36-22-36
# 6796  ZZ Top     Deal Goin' Down
# 6797  ZZ Top  Can't Stop Rockin'
# 6798  ZZ Top   I Got The Message
# 6799  ZZ Top        Antenna Head
#
#                                                    text  number_of_tokens  \
# 0     sometimes when i'm mad  there's a part of me t...              1551
# 1     tried to sneak out without saying  with my lou...              1029
# 2     you feel bad  let me tell you  we all get the ...              1831
# 3     down in the street they're all singing and sho...              1964
# 4     just a notion that's all  just a feeling that ...               514
# ...                                                 ...               ...
# 6795  what  what  what you want? hey  my thing is a ...               646
# 6796  when the deal goin' down and you gonna take yo...               746
# 6797  i heard about the rock for sometime  i know.  ...               995
# 6798  i'm picking up on a signal  that's in the air ...               495
# 6799  old 61's my number on the hi-way  i'm turnin' ...               556
#
#      Genre1 Genre2  check                                                POS
# 0       Pop   Rock   True  mad little sad mean other rainy gloomy funny d...
# 1       Pop   Rock   True  record la la la la red la la la la dead la la ...
# 2       Pop   Rock   True  bad bad bad sad loose cool bright romantic bad...
# 3       Pop   Rock   True  alive dead hollow smart sorry last sorry final...
# 4       Pop   Rock   True  mistaking right wrong special notion feeling m...
# ...     ...    ...    ...                                                ...
# 6795   Rock    Pop   True  real fine real fine round thing thing thing th...
# 6796   Rock    Pop   True  deal chance mystery trance future deal deal no...
# 6797   Rock    Pop   True  easy wrong right low loose high rock roll rock...
# 6798   Rock    Pop   True  straight electric about empty straight straigh...
# 6799   Rock    Pop   True  bad only only red full number hi way v ass way...
#
# [6800 rows x 8 columns]

# %%
artists = list(np.unique(df.artists))
len(artists)
# Out:
# 272

# %%
len(df)
# Out:
# 6800

# %%
df = pd.read_csv("../../songs_plus_dates.csv")

# %%
df
# Out:
#                                 song artist  \
# 0                   Andante, Andante   ABBA
# 1                     As Good As New   ABBA
# 2                   Bang-A-Boomerang   ABBA
# 3                          Cassandra   ABBA
# 4                         Chiquitita   ABBA
# ...                              ...    ...
# 33435               As I Said Before  Zebra
# 33436                          Bears  Zebra
# 33437        Hard Living Without You  Zebra
# 33438             When You Get There  Zebra
# 33439  You're Only Losing Your Heart  Zebra
#
#                                                     link  \
# 0                  /a/abba/andante+andante_20002708.html
# 1                   /a/abba/as+good+as+new_20003033.html
# 2                 /a/abba/bang+a+boomerang_20002668.html
# 3                        /a/abba/cassandra_20002811.html
# 4                       /a/abba/chiquitita_20002978.html
# ...                                                  ...
# 33435            /z/zebra/as+i+said+before_10198473.html
# 33436                       /z/zebra/bears_20456403.html
# 33437     /z/zebra/hard+living+without+you_10198468.html
# 33438          /z/zebra/when+you+get+there_10198475.html
# 33439  /z/zebra/youre+only+losing+your+heart_10198467...
#
#                                                     text  \
# 0      take it easy with me  please  touch me gently ...
# 1      i'll never know why i had to go  why i had to ...
# 2      making somebody happy is a question of give an...
# 3      down in the street they're all singing and sho...
# 4      chiquitita  tell me what's wrong  you're encha...
# ...                                                  ...
# 33435  and i said before  i don't want no more  and i...
# 33436  in the middle of winter  the trees are bare an...
# 33437  nothing to say no place to hide  i can't find ...
# 33438  you wake up in the morning  and you're not fee...
# 33439  don't' do anything i wouldn't do  pass me anyw...
#
#                                             stemmed_text  \
# 0       take it easi with me pleas touch me gentli li...
# 1       i 'll never know whi i had to go whi i had to...
# 2       make somebodi happi is a question of give and...
# 3       down in the street they 're all sing and shou...
# 4       chiquitita tell me what 's wrong you 're ench...
# ...                                                  ...
# 33435   and i said befor i do n't want no more and i ...
# 33436   in the middl of winter the tree are bare and ...
# 33437   noth to say no place to hide i ca n't find a ...
# 33438   you wake up in the morn and you 're not feel ...
# 33439   do n't ' do anyth i would n't do pass me anyw...
#
#                                                      POS  \
# 0      easy slow andante soft light andante strong st...
# 1      lousy rotten tough enough good new good new ne...
# 2      happy little sweet sweet tender dumb dumb dumb...
# 3      alive dead hollow smart sorry last sorry final...
# 4      wrong own sad quiet sure new new hard sad quie...
# ...                                                  ...
# 33435  insane insane sure crazy pleasant little secon...
# 33436  bare only precious cold precious middle winter...
# 33437  good right wrong hard hard rough hard hard har...
# 33438  same gentle alone hard worth front good mornin...
# 33439  back alive unreal critical unusual back alive ...
#
#                                                 POS_tags Genre1       Genre2  \
# 0      ['VB', 'PRP', 'JJ', 'IN', 'PRP', '_SP', 'UH', ...    Pop         Rock
# 1      ['PRP', 'MD', 'RB', 'VB', 'WRB', 'PRP', 'VBD',...    Pop         Rock
# 2      ['VBG', 'NN', 'JJ', 'VBZ', 'DT', 'NN', 'IN', '...    Pop         Rock
# 3      ['IN', 'IN', 'DT', 'NN', 'PRP', 'VBP', 'DT', '...    Pop         Rock
# 4      ['NNP', '_SP', 'VB', 'PRP', 'WP', 'VBZ', 'JJ',...    Pop         Rock
# ...                                                  ...    ...          ...
# 33435  ['CC', 'PRP', 'VBD', 'IN', '_SP', 'PRP', 'VBP'...   Rock   Electronic
# 33436  ['IN', 'DT', 'NN', 'IN', 'NN', '_SP', 'DT', 'N...   Rock   Electronic
# 33437  ['NN', 'TO', 'VB', 'DT', 'NN', 'TO', 'VB', '_S...   Rock   Electronic
# 33438  ['PRP', 'VBP', 'RP', 'IN', 'DT', 'NN', '_SP', ...   Rock   Electronic
# 33439  ['VBP', 'RB', '``', 'VB', 'NN', 'PRP', 'MD', '...   Rock   Electronic
#
#            genre1       genre2  number_of_tokens  number_of_types  date  \
# 0         europop  swedish pop             260.0             87.0  1980
# 1         europop  swedish pop             312.0            120.0  1979
# 2         europop  swedish pop             198.0            101.0  1975
# 3         europop  swedish pop             361.0            157.0  1981
# 4         europop  swedish pop             304.0            119.0  1979
# ...           ...          ...               ...              ...   ...
# 33435  album rock   glam metal             228.0             79.0  1983
# 33436  album rock   glam metal             204.0             97.0  1984
# 33437  album rock   glam metal             165.0             66.0  1986
# 33438  album rock   glam metal             171.0            104.0  1983
# 33439  album rock   glam metal             249.0             88.0  1986
#
#       decades
# 0       1980s
# 1       1970s
# 2       1970s
# 3       1980s
# 4       1970s
# ...       ...
# 33435   1980s
# 33436   1980s
# 33437   1980s
# 33438   1980s
# 33439   1980s
#
# [33440 rows x 15 columns]

# %%
mean ={}
for a in artists:
    mean[a] = int(np.mean(df.number_of_tokens[df.artists==a]))

# %%
ax = sns.distplot(list(mean.values()), rug=True, kde=False)
ax.set_xlabel("song length")
ax.set_ylabel("occurence")
ax.set_title("Distribution of Songlength")
plt.savefig("data25/songlength_dist")
plt.show()

# %%
c = Counter(df.genre1)

# %%
d = Counter(df.genre2)

# %%
d
# Out:
# Counter({'swedish pop': 83,
#          'comic': 53,
#          'pop': 1112,
#          'classic rock': 2368,
#          'mellow gold': 726,
#          'opm': 121,
#          'country road': 153,
#          'art rock': 2523,
#          'blues rock': 1184,
#          'alternative rock': 1076,
#          'folk': 821,
#          'europop': 430,
#          'christian alternative rock': 296,
#          'italian tenor': 9,
#          'brill building pop': 939,
#          'kingston on indie': 61,
#          'candy pop': 54,
#          'dance pop': 684,
#          'british invasion': 353,
#          'dance rock': 1549,
#          'disco': 521,
#          'motown': 138,
#          'jazz blues': 407,
#          'easy listening': 286,
#          'birmingham metal': 313,
#          'britpop': 229,
#          nan: 421,
#          'parody': 16,
#          'rock': 259,
#          'country rock': 937,
#          'heartland rock': 136,
#          'post-teen pop': 50,
#          'oklahoma country': 97,
#          'garage rock': 68,
#          'hollywood': 216,
#          'album rock': 240,
#          'neo mellow': 673,
#          'irish folk': 49,
#          'manila sound': 96,
#          'country': 1175,
#          'edm': 104,
#          'death metal': 243,
#          'hard rock': 463,
#          'new romantic': 257,
#          'art punk': 70,
#          'indonesian pop': 12,
#          'tagalog worship': 33,
#          'canadian pop': 175,
#          'progressive metal': 80,
#          'uk pop': 36,
#          'rock-and-roll': 131,
#          'g funk': 123,
#          'new age': 33,
#          'australian pop': 255,
#          'middle earth': 31,
#          'glam metal': 195,
#          'post-grunge': 89,
#          'gangster rap': 193,
#          'punk': 192,
#          'german pop': 9,
#          'modern rock': 73,
#          'girl group': 11,
#          'chamber pop': 117,
#          'kundiman': 7,
#          'dutch hip hop': 18,
#          'beatlesque': 235,
#          'permanent wave': 339,
#          'classic canadian rock': 48,
#          'rumba': 4,
#          'arkansas country': 93,
#          'latin pop': 45,
#          'canadian country': 133,
#          'cosmic american': 211,
#          'canadian indie': 42,
#          'dirty south rap': 148,
#          'canadian singer-songwriter': 386,
#          'honky tonk': 131,
#          'contemporary vocal jazz': 149,
#          'gothic metal': 128,
#          'electronica': 52,
#          'power pop': 35,
#          'show tunes': 14,
#          'lilith': 147,
#          'ectofolk': 112,
#          'romanian pop': 11,
#          'rap rock': 100,
#          'world worship': 14,
#          'indonesian indie': 14,
#          'hip hop': 49,
#          'mod revival': 69,
#          'folk rock': 205,
#          'classic country pop': 216,
#          'neo soul': 59,
#          'outlaw country': 151,
#          'operatic pop': 56,
#          'country dawn': 128,
#          'lounge': 201,
#          'rap': 58,
#          'ccm': 139,
#          'christian music': 62,
#          'nu metal': 185,
#          'danish metal': 60,
#          'gospel r&b': 98,
#          'new wave pop': 111,
#          'dangdut': 5,
#          'funk metal': 243,
#          'desi pop': 9,
#          'movie tunes': 19,
#          'pop rock': 256,
#          'bubblegum pop': 36,
#          'new orleans rap': 45,
#          'blues': 35,
#          'hardcore hip hop': 68,
#          'dixieland': 81,
#          'rhythm and blues': 8,
#          'lovers rock': 55,
#          'industrial': 107,
#          'dream pop': 30,
#          'hip house': 13,
#          'alternative metal': 110,
#          'australian rock': 26,
#          'metal': 158,
#          'soft rock': 269,
#          'r&b': 100,
#          'new jersey hardcore': 93,
#          'glam rock': 8,
#          'canadian rock': 176,
#          'hip pop': 35,
#          'finnish power metal': 67,
#          'grunge': 173,
#          'eurodance': 7,
#          'madchester': 148,
#          'israeli singer-songwriter': 6,
#          'electro house': 3,
#          'australian dance': 47,
#          'piano rock': 26,
#          'groove metal': 52,
#          'folk metal': 13,
#          'funk': 219,
#          'nashville sound': 66,
#          'art pop': 184,
#          'reggae': 42,
#          'pop rap': 18,
#          'rock drums': 88,
#          'jam band': 104,
#          'latin': 37,
#          'celtic punk': 71,
#          'funk rock': 86,
#          'east coast hip hop': 38,
#          'ethereal wave': 6,
#          'icelandic rock': 5,
#          'e6fi': 15,
#          'emo': 66,
#          'neon pop punk': 5,
#          "children's folk": 32,
#          'german metal': 6,
#          'early us punk': 122,
#          'classic soul': 55,
#          'german hard rock': 111,
#          'ska mexicano': 60,
#          'orgcore': 9,
#          'k-pop boy group': 1,
#          'uk reggae': 95,
#          'bronx hip hop': 10,
#          'melodic metalcore': 41,
#          'big beat': 48,
#          'deathcore': 28,
#          'boston punk': 16,
#          'pop punk': 58,
#          'japanese singer-songwriter': 19,
#          'urban contemporary': 22,
#          'miami hip hop': 17,
#          'black thrash': 42,
#          'reggae fusion': 17,
#          'indie poptimism': 10,
#          'celtic rock': 53,
#          'modern power pop': 65,
#          'comedy rock': 98,
#          'british blues': 61,
#          'roots rock': 74,
#          'pittsburgh rap': 34,
#          'post-punk': 13,
#          'australian reggae fusion': 30,
#          'old school thrash': 4,
#          'crunk': 91,
#          'anti-folk': 43,
#          'experimental pop': 30,
#          'bluegrass': 5,
#          'australian indie': 30,
#          'crossover thrash': 12,
#          'west coast rap': 4,
#          'christian metal': 21,
#          'electropop': 9,
#          'electro-industrial': 1,
#          'roots reggae': 23,
#          'italian pop': 13,
#          'electroclash': 6,
#          'disco house': 12,
#          'canterbury scene': 2})

# %%
ax = sns.distplot(list(c.values()))
ax.set_xlabel("number of genres")
ax.set_ylabel("occurence")
plt.title("Number of genres per artist")
#plt.savefig("data25/genres1_per_artist")

# %%
ax = sns.distplot(list(d.values()))
ax.set_xlabel("number of genres")
ax.set_ylabel("occurence")
plt.title("Number of genres per artist")
plt.savefig("data25/genres2_per_artist")

# %%
ax = sns.distplot((list(c.values())))
ax = sns.distplot(list(d.values()));
ax.set_xlabel("number of songs")
ax.set_ylabel("occurence")
plt.title("Number of songs per artist")
plt.savefig("data25/genres_all_per_artist")

# %%
counts = Counter(df.genre1)
plt.figure(figsize=(15,10))
plt.pie([float(v) for v in counts.values()], labels=[str(k) for k in counts],
           autopct=None, textprops={'fontsize': 11})
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.savefig("../../images/data25/new_genre1_all")

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,15))


plt.bar(range(len(c)), c.keys(), align='center')
plt.xticks(range(len(c)), list(c.values()), rotation = 45)

plt.show()

# %%
counts = Counter(df.Genre1)
plt.pie([float(v) for v in counts.values()], labels=[str(k) for k in counts],
           autopct=None, textprops={'fontsize': 20},  radius=4, labeldistance=6, rotatelabels = False)
plt.savefig("data25/genre2_all")

# %%
fig, ax = plt.subplots(figsize=(15,7))
ax.set_xlabel('number of artists', fontsize = 15)
ax.set_ylabel('number of tokens', fontsize = 15)
df.groupby('artists')['number_of_tokens'].plot(ax=ax, legend = True)
plt.savefig("data25/number_of_tokens")

# %%
df = df[df['Genre1'].notnull()]

# %%
data1 = df[df['Genre1'] == 'Rock']

# %%
data2 = df[df['Genre1'] == 'Pop']
data3 = df[df['Genre1'] == 'Jazz']
data4 = df[df['Genre1'] == 'Electronic']
data5 = df[df['Genre1'] == 'Funk / Soul']
data6 = df[df['Genre1'] == 'Reggae']
data7 = df[df['Genre1'] == 'Hip Hop']
data8 = df[df['Genre1'] == 'Stage & Screen']
data9 = df[df['Genre1'] == 'Classical']
data10 = df[df['Genre1'] == 'Latin']

# %%
data1['text'].value_counts().hist()

# %%
data1['POS'].dropna(inplace=True)

# %%
list_of_names = data1['POS'].values.tolist()

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.probability import FreqDist
import matplotlib.pyplot as plt
counter = 0
wordFiltered = []
for l in list_of_names:
    tokens = word_tokenize(l) 
    for w in tokens:
        wordFiltered.append(w)
        counter += 1

# %%
counts_rock = Counter(wordFiltered)

# %%
freq_df = pd.DataFrame.from_records(counts_rock.most_common(20), columns=['token', 'count'])

freq_df.plot(kind = 'barh', x = 'token', figsize=(5,5), title = 'POS Rock', fontsize=12)
plt.savefig("../../images/data25/rock_most_common_words_pos")

# %%
df.dtypes
# Out:
# song                 object
# artist               object
# link                 object
# text                 object
# stemmed_text         object
# POS                  object
# POS_tags             object
# Genre1               object
# Genre2               object
# genre1               object
# genre2               object
# number_of_tokens    float64
# number_of_types     float64
# date                  int64
# decades              object
# dtype: object
