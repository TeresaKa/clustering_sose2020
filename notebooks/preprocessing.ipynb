# %%
import pandas as pd
import numpy as np
from collections import Counter

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# load raw data

# %%
songs = pd.read_csv("../songdata.csv")
songs
# Out:
#              artist                   song  \
# 0              ABBA  Ahe's My Kind Of Girl
# 1              ABBA       Andante, Andante
# 2              ABBA         As Good As New
# 3              ABBA                   Bang
# 4              ABBA       Bang-A-Boomerang
# ...             ...                    ...
# 57645  Ziggy Marley          Good Old Days
# 57646  Ziggy Marley          Hand To Mouth
# 57647          Zwan           Come With Me
# 57648          Zwan                 Desire
# 57649          Zwan              Heartsong
#
#                                               link  \
# 0       /a/abba/ahes+my+kind+of+girl_20598417.html
# 1            /a/abba/andante+andante_20002708.html
# 2             /a/abba/as+good+as+new_20003033.html
# 3                       /a/abba/bang_20598415.html
# 4           /a/abba/bang+a+boomerang_20002668.html
# ...                                            ...
# 57645  /z/ziggy+marley/good+old+days_10198588.html
# 57646  /z/ziggy+marley/hand+to+mouth_20531167.html
# 57647           /z/zwan/come+with+me_20148981.html
# 57648                 /z/zwan/desire_20148986.html
# 57649              /z/zwan/heartsong_20148991.html
#
#                                                     text
# 0      Look at her face, it's a wonderful face  \nAnd...
# 1      Take it easy with me, please  \nTouch me gentl...
# 2      I'll never know why I had to go  \nWhy I had t...
# 3      Making somebody happy is a question of give an...
# 4      Making somebody happy is a question of give an...
# ...                                                  ...
# 57645  Irie days come on play  \nLet the angels fly l...
# 57646  Power to the workers  \nMore power  \nPower to...
# 57647  all you need  \nis something i'll believe  \nf...
# 57648  northern star  \nam i frightened  \nwhere can ...
# 57649  come in  \nmake yourself at home  \ni'm a bit ...
#
# [57650 rows x 4 columns]

# %%
for i, row in songs.iterrows():
    row.text = row.text.replace(',',' ').replace('\n', '').replace("[Chorus]", "").lower().split()
songs
# Out:
#              artist                   song  \
# 0              ABBA  Ahe's My Kind Of Girl
# 1              ABBA       Andante, Andante
# 2              ABBA         As Good As New
# 3              ABBA                   Bang
# 4              ABBA       Bang-A-Boomerang
# ...             ...                    ...
# 57645  Ziggy Marley          Good Old Days
# 57646  Ziggy Marley          Hand To Mouth
# 57647          Zwan           Come With Me
# 57648          Zwan                 Desire
# 57649          Zwan              Heartsong
#
#                                               link  \
# 0       /a/abba/ahes+my+kind+of+girl_20598417.html
# 1            /a/abba/andante+andante_20002708.html
# 2             /a/abba/as+good+as+new_20003033.html
# 3                       /a/abba/bang_20598415.html
# 4           /a/abba/bang+a+boomerang_20002668.html
# ...                                            ...
# 57645  /z/ziggy+marley/good+old+days_10198588.html
# 57646  /z/ziggy+marley/hand+to+mouth_20531167.html
# 57647           /z/zwan/come+with+me_20148981.html
# 57648                 /z/zwan/desire_20148986.html
# 57649              /z/zwan/heartsong_20148991.html
#
#                                                     text
# 0      [look, at, her, face, it's, a, wonderful, face...
# 1      [take, it, easy, with, me, please, touch, me, ...
# 2      [i'll, never, know, why, i, had, to, go, why, ...
# 3      [making, somebody, happy, is, a, question, of,...
# 4      [making, somebody, happy, is, a, question, of,...
# ...                                                  ...
# 57645  [irie, days, come, on, play, let, the, angels,...
# 57646  [power, to, the, workers, more, power, power, ...
# 57647  [all, you, need, is, something, i'll, believe,...
# 57648  [northern, star, am, i, frightened, where, can...
# 57649  [come, in, make, yourself, at, home, i'm, a, b...
#
# [57650 rows x 4 columns]

# %% [markdown]
# remove artists with less than 60 songs

# %%
c = Counter(songs.artist)

# %%
for v, k in c.items():
    if k<60:
        songs = songs[songs.artist!=v]

# %%
songs['number_of_tokens'] = songs.text.str.len()

# %%
songs.drop('link', axis=1, inplace=True)
songs
# Out:
#              artist                   song  \
# 0              ABBA  Ahe's My Kind Of Girl
# 1              ABBA       Andante, Andante
# 2              ABBA         As Good As New
# 3              ABBA                   Bang
# 4              ABBA       Bang-A-Boomerang
# ...             ...                    ...
# 57642  Ziggy Marley                 Friend
# 57643  Ziggy Marley                     G7
# 57644  Ziggy Marley             Generation
# 57645  Ziggy Marley          Good Old Days
# 57646  Ziggy Marley          Hand To Mouth
#
#                                                     text  number_of_tokens
# 0      [look, at, her, face, it's, a, wonderful, face...               153
# 1      [take, it, easy, with, me, please, touch, me, ...               260
# 2      [i'll, never, know, why, i, had, to, go, why, ...               312
# 3      [making, somebody, happy, is, a, question, of,...               200
# 4      [making, somebody, happy, is, a, question, of,...               198
# ...                                                  ...               ...
# 57642  [i, wanna, thank, you, for, the, things, you'v...               132
# 57643  [seven, richest, countries, in, the, world, th...               283
# 57644  [many, generation, have, passed, away, fightin...               251
# 57645  [irie, days, come, on, play, let, the, angels,...               175
# 57646  [power, to, the, workers, more, power, power, ...               579
#
# [50832 rows x 4 columns]

# %%
songs.to_csv("songtexte_bereinigt_gekuerzt")

# %% [markdown]
# #### sample data

# %%
songs_sample = songs.copy()
songs_sample = songs_sample.sample(frac=.25, replace=False, random_state=42)
songs_sample
# Out:
#                    artist                          song  \
# 20468           Van Halen        Take Your Whiskey Home
# 41605           Lil Wayne                     Army Gunz
# 52292       Stevie Wonder              Isn't She Lovely
# 42697        Mariah Carey                  O Holy Night
# 27993               Clash  I'm So Bored With The U.S.A.
# ...                   ...                           ...
# 25325      Billie Holiday                My Last Affair
# 28783  Dave Matthews Band             The Space Between
# 18645             Squeeze            Crying In My Sleep
# 32684        Foo Fighters                    Dear Lover
# 9201           Jason Mraz              Kickin' With You
#
#                                                     text  number_of_tokens
# 20468  [well, my, baby, she, don't, want, me, around....               224
# 41605  [yeah, yeah, yeah, (i, got, army, gunz), yeah,...               578
# 52292  [isn't, she, lovely, isn't, she, wonderful, is...               108
# 42697  [o, holy, night, the, stars, are, brightly, sh...                78
# 27993  [yankee, soldier, he, want, to, shoot, some, s...               113
# ...                                                  ...               ...
# 25325  [can't, you, see, what, love, and, romance, ha...                97
# 28783  [you, cannot, quit, me, so, quickly, is, no, h...               310
# 18645  [breaking, up, is, breaking, my, heart, is, sh...               178
# 32684  [dear, lover, do, you, remember?, the, sound, ...               134
# 9201   [ahhhh, oh, kickin', with, you, wooh, huh, yea...               311
#
# [12708 rows x 4 columns]

# %%
songs_sample.to_csv("sample_25percent.csv")
