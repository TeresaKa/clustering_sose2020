# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns

from sklearn.preprocessing import normalize
from sklearn.cluster import KMeans 
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics import pairwise_distances
from sklearn.metrics import silhouette_score

# %%
songs = pd.read_csv("../../songs_plus_dates.csv")
songs.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                         song         artist  \
# 0         291           291           Dimming Of The Day  Alison Krauss
# 1         292           292  Dreaming My Dreams With You  Alison Krauss
# 2         293           293                Foolish Heart  Alison Krauss
# 3         294           294           If I Give My Heart  Alison Krauss
# 4         295           295     In The Palm Of Your Hand  Alison Krauss
#
#                                                 text  \
# 0  this old house is falling down around my ears ...
# 1  i hope that i won't be that wrong anymore  i h...
# 2  i think i'll take my foolish heart  my friend ...
# 3  if i give my heart to you tonight  will you st...
# 4  if i could have the world and all it owns  a t...
#
#                                         stemmed_text  \
# 0   thi old hous is fall down around my ear I 'm ...
# 1   I hope that I wo n't be that wrong anymor I h...
# 2   I think I 'll take my foolish heart , my frie...
# 3   If I give my heart to you tonight will you st...
# 4   If I could have the world and all it own A th...
#
#                                                  POS  number_of_tokens  \
# 0  old broken broken house river will dimming day...               809
# 1  wrong time way mind love hope hope hope find '...               652
# 2  foolish only blue true deep extra many many bl...              1072
# 3  ours faded ours ours heart tonight side mornin...               770
# 4  only selfish little rich poor free rich poor w...              1027
#
#                    Genre1 Genre2  date decades
# 0  Folk, World, & Country   Rock  2012   2010s
# 1  Folk, World, & Country   Rock  1999   1990s
# 2  Folk, World, & Country   Rock  1987   1980s
# 3  Folk, World, & Country   Rock  1987   1980s
# 4  Folk, World, & Country   Rock  1995   1990s

# %%
songs = songs[songs.Genre1 != "Pop"]
songs = songs[songs.Genre1 != "Rock"]
songs
# Out:
#       Unnamed: 0  Unnamed: 0.1                                        song  \
# 0            291           291                          Dimming Of The Day
# 1            292           292                 Dreaming My Dreams With You
# 2            293           293                               Foolish Heart
# 3            294           294                          If I Give My Heart
# 4            295           295                    In The Palm Of Your Hand
# ...          ...           ...                                         ...
# 3718       15801         15801  Tie A Yellow Ribbon Round The Old Oak Tree
# 3719       15802         15802                        To Love The Language
# 3720       15803         15803               When My Heart Finds Christmas
# 3721       15804         15804                           Whisper Your Name
# 3722       15805         15805                            With Imagination
#
#                   artist                                               text  \
# 0          Alison Krauss  this old house is falling down around my ears ...
# 1          Alison Krauss  i hope that i won't be that wrong anymore  i h...
# 2          Alison Krauss  i think i'll take my foolish heart  my friend ...
# 3          Alison Krauss  if i give my heart to you tonight  will you st...
# 4          Alison Krauss  if i could have the world and all it owns  a t...
# ...                  ...                                                ...
# 3718  Harry Connick, Jr.  i'm comin home i done my time now i got to kno...
# 3719  Harry Connick, Jr.  i is just what i was   and am ain't who i be. ...
# 3720  Harry Connick, Jr.  in my eyes are valentines  and easter eggs and...
# 3721  Harry Connick, Jr.  somebody was spreading rumors  'bout better da...
# 3722  Harry Connick, Jr.  i've travelled many a mile  and i haven't foun...
#
#                                            stemmed_text  \
# 0      thi old hous is fall down around my ear I 'm ...
# 1      I hope that I wo n't be that wrong anymor I h...
# 2      I think I 'll take my foolish heart , my frie...
# 3      If I give my heart to you tonight will you st...
# 4      If I could have the world and all it own A th...
# ...                                                 ...
# 3718   I 'm comin home I done my time now I got to k...
# 3719   I is just what I wa , and am ai n't who I be ...
# 3720   In my eye are valentin and easter egg and new...
# 3721   somebodi wa spread rumor 'bout better day a c...
# 3722   I 've travel mani a mile and I have n't found...
#
#                                                     POS  number_of_tokens  \
# 0     old broken broken house river will dimming day...               809
# 1     wrong time way mind love hope hope hope find '...               652
# 2     foolish only blue true deep extra many many bl...              1072
# 3     ours faded ours ours heart tonight side mornin...               770
# 4     only selfish little rich poor free rich poor w...              1027
# ...                                                 ...               ...
# 3718  free yellow ole long ole yellow ole key simple...              1110
# 3719  good sweet live language language mama somethi...               811
# 3720  new new kind easter year wine heart heart time...               524
# 3721  same own own true only lonely Somebody comin n...               644
# 3722  own strong next strong harsh holy weary weary ...              1214
#
#                       Genre1 Genre2  date decades
# 0     Folk, World, & Country   Rock  2012   2010s
# 1     Folk, World, & Country   Rock  1999   1990s
# 2     Folk, World, & Country   Rock  1987   1980s
# 3     Folk, World, & Country   Rock  1987   1980s
# 4     Folk, World, & Country   Rock  1995   1990s
# ...                      ...    ...   ...     ...
# 3718                    Jazz    Pop  2001   2000s
# 3719                    Jazz    Pop  1994   1990s
# 3720                    Jazz    Pop  1993   1990s
# 3721                    Jazz    Pop  1994   1990s
# 3722                    Jazz    Pop  1991   1990s
#
# [3723 rows x 12 columns]

# %% [markdown]
# ### prepare data

# %%
raw_text = songs['text']
POS = songs['POS']
stemmed = songs['stemmed_text']

# %%
def tfidf(text):
    tfidf = TfidfVectorizer()
    tf_idf = tfidf.fit_transform(text)
    tf_idf_norm = normalize(tf_idf)
    tf_idf_array = tf_idf_norm.toarray()
    return tf_idf_array

# %% [markdown]
# ### Silhouetten-Koeffizient

# %%
metric_silhouette = []
for n in range(1, 10):
    model = KMeans(n_clusters=n)
    model.fit(tf_idf)
    if n > 1:  #silhouette_score needs at least 2 cluster to work
        metric_silhouette.append(silhouette_score(tf_idf, model.labels_))


plt.title('Silhouetten-Koeffizient')
plt.plot(range(2,10), metric_silhouette)

# %% [markdown]
# ### KMeans

# %%
def kmeans(n_clusters, text):
    kmean = KMeans(n_clusters=5, algorithm = 'auto') #max_iter=600
    fitted = kmean.fit(text)
    prediction = kmean.predict(text)
    return prediction

# %%
def compute_PCA(text):
    pca = PCA(n_components = 2)
    Y = pca.fit_transform(text)
    return Y

# %%
def plot_PCA(Y, prediction):
    plt.figure(figsize=(15,10))
    plt.scatter(Y[:, 0], Y[:, 1], c=prediction, s=50, cmap='viridis')
    plt.title('PCA')
# plt.savefig('K_Means/PCA_K-Means_POS.png', bbox_inches = "tight")

# %%
def KMeans_all(text, n_clusters):
    data = tfidf(text)
    prediction = kmeans(n_clusters,data)
    Y = compute_PCA(data)
    return Y, prediction

# %%
def plot_kmeans_plus_labels(Y, prediction, labels):
    markers = ('o', 'v', '^', 's', 'p', '*','d', 'P', 'X', '<')
    plt.figure(figsize=(15,10))
    sns.scatterplot(Y[:, 0], Y[:, 1],hue=prediction, style=labels, markers=markers, palette=sns.color_palette("hls", len(np.unique(prediction))))

    plt.title('KMeans and decade labels')
    # plt.savefig('kmeans_tsne_genremarkers.png')

# %%
Y, prediction = KMeans_all(raw_text, 10)
plot_PCA(Y, prediction)

# %%
plot_kmeans_plus_labels(Y, prediction, songs.decades)

# %%
twothousands = songs[songs.decades=='2000s']
twothousands
# Out:
#       Unnamed: 0  Unnamed: 0.1                                           song  \
# 5            296           296                             Lay Down Beside Me
# 8            299           299  Shimmy Down The Chimney (Fill Up My Stocking)
# 25           411           411                                Bottle Of Booze
# 36           422           422                              I Pulled My Groin
# 43           429           429                                 Particle Board
# ...          ...           ...                                            ...
# 3706       15789         15789                       Nothin' New For New Year
# 3712       15795         15795                                 Sheik Of Araby
# 3716       15799         15799                            The Lonely Goatherd
# 3717       15800         15800                       The Way You Look Tonight
# 3718       15801         15801     Tie A Yellow Ribbon Round The Old Oak Tree
#
#                   artist                                               text  \
# 5          Alison Krauss  i've spent my life  lookin' for you  findin' m...
# 8          Alison Krauss  tonight  i waited but my heart is so cold  'ca...
# 25        Arrogant Worms  there are many wonders in the usa  the cities ...
# 36        Arrogant Worms  i pulled my groin  it's the very best injury  ...
# 43        Arrogant Worms  well my baby came at me with a 2x4  so i fough...
# ...                  ...                                                ...
# 3706  Harry Connick, Jr.  i see my own reflection in the window  i hear ...
# 3712  Harry Connick, Jr.  well  i'm the sheik of araby and your love  we...
# 3716  Harry Connick, Jr.  high on a hill was a lonely goatherd  lay ee o...
# 3717  Harry Connick, Jr.  someday  when i'm awfully low  when the world ...
# 3718  Harry Connick, Jr.  i'm comin home i done my time now i got to kno...
#
#                                            stemmed_text  \
# 5      I 've spent my life lookin ' for you findin '...
# 8      tonight , I wait but my heart is so cold 'cau...
# 25     there are mani wonder in the usa the citi and...
# 36     I pull my groin It 's the veri best injuri th...
# 43     well my babi came at me with a 2x4 So I fough...
# ...                                                 ...
# 3706   I see my own reflect in the window I hear the...
# 3712   well , I 'm the sheik of arabi and your love ...
# 3716   high on a hill wa a lone goatherd lay ee odl ...
# 3717   someday , when I 'm aw low when the world is ...
# 3718   I 'm comin home I done my time now I got to k...
#
#                                                     POS  number_of_tokens  \
# 5     easy worth close same close life way while mil...               653
# 8     cold other loving Tonight heart minute job dar...              1185
# 25    many great successful sad sad yer hooray joy h...              2026
# 36    happy groin injury groin groin hand groin groi...               712
# 43    rough awful flat useful fluff enough baby sand...              1755
# ...                                                 ...               ...
# 3706  own own accustomed used new new new new new ne...              1189
# 3712  asleep asleep asleep love night tent way land ...               767
# 3716  High lonely lay lonely remote lay clear lay la...              1657
# 3717  low cold lovely warm soft foolish Lovely fooli...               849
# 3718  free yellow ole long ole yellow ole key simple...              1110
#
#                       Genre1 Genre2  date decades
# 5     Folk, World, & Country   Rock  2007   2000s
# 8     Folk, World, & Country   Rock  2007   2000s
# 25    Folk, World, & Country   Rock  2004   2000s
# 36    Folk, World, & Country   Rock  2004   2000s
# 43    Folk, World, & Country   Rock  2004   2000s
# ...                      ...    ...   ...     ...
# 3706                    Jazz    Pop  2003   2000s
# 3712                    Jazz    Pop  2007   2000s
# 3716                    Jazz    Pop  2001   2000s
# 3717                    Jazz    Pop  2009   2000s
# 3718                    Jazz    Pop  2001   2000s
#
# [774 rows x 12 columns]
