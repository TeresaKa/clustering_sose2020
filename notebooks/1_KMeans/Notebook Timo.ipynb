# %%
import pandas as pd
df = pd.read_csv("../songtexte_bereinigt_gekuerzt.csv")

# %%
df
# Out:
#        Unnamed: 0        artist                   song  \
# 0               0          ABBA  Ahe's My Kind Of Girl
# 1               1          ABBA       Andante, Andante
# 2               2          ABBA         As Good As New
# 3               3          ABBA                   Bang
# 4               4          ABBA       Bang-A-Boomerang
# ...           ...           ...                    ...
# 50827       57642  Ziggy Marley                 Friend
# 50828       57643  Ziggy Marley                     G7
# 50829       57644  Ziggy Marley             Generation
# 50830       57645  Ziggy Marley          Good Old Days
# 50831       57646  Ziggy Marley          Hand To Mouth
#
#                                                     text  number_of_tokens
# 0      look at her face  it's a wonderful face  and i...               741
# 1      take it easy with me  please  touch me gently ...              1381
# 2      i'll never know why i had to go  why i had to ...              1438
# ...

# %%
df.shape
# Out:
# (50832, 5)

# %%
df.text
# Out:
# 0        look at her face  it's a wonderful face  and i...
# 1        take it easy with me  please  touch me gently ...
# 2        i'll never know why i had to go  why i had to ...
# 3        making somebody happy is a question of give an...
# 4        making somebody happy is a question of give an...
#                                ...
# 50827      i wanna thank you for the things you've done...
# 50828    seven richest countries in the world  them hav...
# 50829    many generation have passed away  fighting for...
# 50830    irie days come on play  let the angels fly let...
# 50831    power to the workers  more power  power to the...
# Name: text, Length: 50832, dtype: object

# %%
df.artist.dropna()
# Out:
# 0                ABBA
# 1                ABBA
# 2                ABBA
# 3                ABBA
# 4                ABBA
#              ...
# 50827    Ziggy Marley
# 50828    Ziggy Marley
# 50829    Ziggy Marley
# 50830    Ziggy Marley
# 50831    Ziggy Marley
# Name: artist, Length: 50832, dtype: object

# %%
a = df.artist.unique()

# %%
a.shape
# Out:
# (415,)

# %%
df.groupby('artist').song.count().plot(kind='bar').set_xlabel('Bands')
# Out:
# Text(0.5, 0, 'Bands')

# %% [markdown]
# # UMAP

# %% [markdown]
# ### Mit Songtexte_bereinigt_gekuerzt.csv und den 5 häufigsten Bands

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from collections import Counter
import umap

# %%
from yellowbrick.text import UMAPVisualizer
# Out:
# /home/teresa/.local/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
import pandas as pd
df = pd.read_csv("../../currently_dataset/song_decades_long.csv")

# %%
c = Counter(df.artist).most_common()[5:]

# %%
sample = df.copy()
for el in c:
    sample = sample[sample.artist!=el[0]]
sample
# Out:
#      Unnamed: 0              artist decades  \
# 13          206           Aerosmith   1970s
# 14          218           Aerosmith   1980s
# 15          230           Aerosmith   1990s
# 16          248           Aerosmith   2000s
# 17          258           Aerosmith   2010s
# 67          928           Bob Dylan   1960s
# 68          954           Bob Dylan   1970s
# 69          973           Bob Dylan   1980s
# 70          984           Bob Dylan   1990s
# 71          999           Bob Dylan   2000s
# 72         1008           Bob Dylan   2010s
# 90         1234   Bruce Springsteen   1970s
# 91         1241   Bruce Springsteen   1980s
# 92         1261   Bruce Springsteen   1990s
# 93         1281   Bruce Springsteen   2000s
# 94         1299   Bruce Springsteen   2010s
# 95         1309   Bruce Springsteen   2020s
# 172        2234        Dolly Parton   1960s
# 173        2238        Dolly Parton   1970s
# 174        2257        Dolly Parton   1980s
# ...

# %%
tfidf = TfidfVectorizer()
docs = tfidf.fit_transform(sample.text)
labels = sample.artist

# %%
umap = UMAPVisualizer()
umap.fit(docs, labels)
umap.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...

# %% [markdown]
# ### mit Sample_25_percent.csv und den 5 häufgisten Bands

# %%
df = pd.read_csv("../sample_25percent.csv")

# %%
c = Counter(df.artist).most_common()[5:]

# %%
sample = df.copy()
for el in c:
    sample = sample[sample.artist!=el[0]]
sample
# Out:
#        Unnamed: 0             artist                           song  \
# 66           8438       Indigo Girls    Everything In It's Own Time
# 74           7501  Hank Williams Jr.             The Cheatin' Hotel
# 131          8449       Indigo Girls         Heartache For Everyone
# 133          7498  Hank Williams Jr.                   Tee Tot Song
# 136         33842      George Strait               Back To Bein' Me
# ...           ...                ...                            ...
# 12565       35292  Hank Williams Jr.               I've Been Around
# 12581       13057   Michael W. Smith                          A Way
# 12636       43840   Michael W. Smith                      Above All
# 12652       33884      George Strait  I Met A Friend Of Yours Today
# 12694        6731      George Strait              Christmas Cookies
#
#                                                     text  number_of_tokens
# 66     remember everything i told you  keep it in you...              1098
# ...

# %%
tfidf = TfidfVectorizer()
docs = tfidf.fit_transform(sample.text)
labels = sample.artist

# %%
umap = UMAPVisualizer()
umap.fit(docs, labels)
umap.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...

# %% [markdown]
# ### Mit Songtexte_bereinigt_gekuerzt.csv aber mit allen Bands

# %%
df = pd.read_csv("../songtexte_bereinigt_gekuerzt.csv")

# %%
df.head(2)
# Out:
#    Unnamed: 0 artist                   song  \
# 0           0   ABBA  Ahe's My Kind Of Girl
# 1           1   ABBA       Andante, Andante
#
#                                                 text  number_of_tokens
# 0  look at her face  it's a wonderful face  and i...               741
# 1  take it easy with me  please  touch me gently ...              1381

# %%
tfidf = TfidfVectorizer()
docs = tfidf.fit_transform(df.text)
labels = df.artist

# %%
umap = UMAPVisualizer()
umap.fit(docs)
umap.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numba\compiler.py:602: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "..\..\..\..\..\ProgramData\Anaconda3\lib\site-packages\umap\sparse.py", line 176:
#     @numba.njit(parallel=True)
#     def nn_descent(
#     ^
#
#   self.func_ir.loc))
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# ### mit Sample_25_percent.csv aber mit allen Bands

# %%
df = pd.read_csv("../sample_25percent.csv")

# %%
df.head(2)
# Out:
#    Unnamed: 0     artist                    song  \
# 0       20468  Van Halen  Take Your Whiskey Home
# 1       41605  Lil Wayne               Army Gunz
#
#                                                 text  number_of_tokens
# 0  well  my baby  she don't want me around.  she ...              1197
# 1    yeah yeah yeah (i got army gunz)  yeah yeah ...              2860

# %%
tfidf = TfidfVectorizer()
docs = tfidf.fit_transform(df.text)
labels = df.artist

# %%
umap = UMAPVisualizer()
umap.fit(docs, labels)
umap.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numba\compiler.py:602: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "..\..\..\..\..\ProgramData\Anaconda3\lib\site-packages\umap\sparse.py", line 176:
#     @numba.njit(parallel=True)
#     def nn_descent(
#     ^
#
#   self.func_ir.loc))
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...

# %% [markdown]
# ## UMAP mit Songs_100.csv

# %%
df = pd.read_csv("../songs_100.csv")

# %%
df.head(2)
# Out:
#    Unnamed: 0 artists                    song  \
# 0           0    ABBA  I Saw It In The Mirror
# 1           1    ABBA          Reina Danzante
#
#                                                 text  number_of_tokens  check  \
# 0  i saw it in the mirror  i saw it in my face  t...               803  False
# 1  you can dance  you can jive  having the time o...              1106  False
#
#   Genre1 Genre2
# 0    Pop   Rock
# 1    Pop   Rock

# %%
tfidf = TfidfVectorizer()
docs = tfidf.fit_transform(df.text)
labels = df.artists

# %%
umap = UMAPVisualizer()
umap.fit(docs, labels)
umap.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numba\compiler.py:602: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "..\..\..\..\..\ProgramData\Anaconda3\lib\site-packages\umap\sparse.py", line 176:
#     @numba.njit(parallel=True)
#     def nn_descent(
#     ^
#
#   self.func_ir.loc))
# C:\ProgramData\Anaconda3\lib\site-packages\umap\spectral.py:229: UserWarning: Embedding a total of 2 separate connected components using meta-embedding (experimental)
#   n_components
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...

# %% [markdown]
# ## UMAP mit songs_25.csv

# %%
df = pd.read_csv("../songs_25.csv")

# %%
df.head(2)
# Out:
#    Unnamed: 0 artists          song  \
# 0           0    ABBA      Me And I
# 1           1    ABBA  My Mama Said
#
#                                                 text  number_of_tokens Genre1  \
# 0  sometimes when i'm mad  there's a part of me t...              1551    Pop
# 1  tried to sneak out without saying  with my lou...              1029    Pop
#
#   Genre2  check                                                POS
# 0   Rock   True  mad little sad mean other rainy gloomy funny d...
# 1   Rock   True  record la la la la red la la la la dead la la ...

# %%
tfidf = TfidfVectorizer()
docs = tfidf.fit_transform(df.text)
labels = df.artists

# %%
umap = UMAPVisualizer(metric='cosine')
umap.fit(docs, labels)
umap.show()
umap.savefig("UMAP_Songs_25_Lyrics")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numba\compiler.py:602: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "..\..\..\..\..\ProgramData\Anaconda3\lib\site-packages\umap\sparse.py", line 176:
#     @numba.njit(parallel=True)
#     def nn_descent(
#     ^
#
#   self.func_ir.loc))
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...

# %% [markdown]
# ## UMAP mit Songs_25.csv mit KMeans

# %%
tfidf = TfidfVectorizer()
docs = tfidf.fit_transform(df.text)
labels = df.Genre1

clusters = KMeans(n_clusters=5)
clusters.fit(docs)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
umap = UMAPVisualizer()
umap.fit(docs, labels)
umap.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numba\compiler.py:602: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "..\..\..\..\..\ProgramData\Anaconda3\lib\site-packages\umap\sparse.py", line 176:
#     @numba.njit(parallel=True)
#     def nn_descent(
#     ^
#
#   self.func_ir.loc))
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...

# %% [markdown]
# ## UMAP mit songs_25.csv + POS

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from yellowbrick.text import UMAPVisualizer

# %%
import pandas as pd

# %%
df = pd.read_csv("../songs_25.csv")

# %%
df.head(2)
# Out:
#    Unnamed: 0 artists          song  \
# 0           0    ABBA      Me And I
# 1           1    ABBA  My Mama Said
#
#                                                 text  number_of_tokens Genre1  \
# 0  sometimes when i'm mad  there's a part of me t...              1551    Pop
# 1  tried to sneak out without saying  with my lou...              1029    Pop
#
#   Genre2  check                                                POS
# 0   Rock   True  mad little sad mean other rainy gloomy funny d...
# 1   Rock   True  record la la la la red la la la la dead la la ...

# %%
tfidf = TfidfVectorizer()
features = tfidf.fit_transform(df.POS.values.astype(str)) 
labels = df.artists

# %%
umap = UMAPVisualizer()
umap.fit(features, labels)
umap.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numba\compiler.py:602: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "..\..\..\..\..\ProgramData\Anaconda3\lib\site-packages\umap\sparse.py", line 176:
#     @numba.njit(parallel=True)
#     def nn_descent(
#     ^
#
#   self.func_ir.loc))
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...

# %% [markdown]
# ## UMAP mit den 5 häufigsten Bands

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from yellowbrick.text import UMAPVisualizer
from collections import Counter

# %%
import pandas as pd

# %%
df = pd.read_csv("../songs_25.csv")

# %%
df.head(2)
# Out:
#    Unnamed: 0 artists          song  \
# 0           0    ABBA      Me And I
# 1           1    ABBA  My Mama Said
#
#                                                 text  number_of_tokens Genre1  \
# 0  sometimes when i'm mad  there's a part of me t...              1551    Pop
# 1  tried to sneak out without saying  with my lou...              1029    Pop
#
#   Genre2  check                                                POS
# 0   Rock   True  mad little sad mean other rainy gloomy funny d...
# 1   Rock   True  record la la la la red la la la la dead la la ...

# %%
c = Counter(df.Genre1).most_common()[5:]

# %%
sample = df.copy()
for el in c:
    sample = sample[sample.Genre1!=el[0]]
sample
# Out:
#       Unnamed: 0 artists                song  \
# 0              0    ABBA            Me And I
# 1              1    ABBA        My Mama Said
# 2              2    ABBA   Hole In Your Soul
# 3              3    ABBA           Cassandra
# 4              4    ABBA       Just A Notion
# ...          ...     ...                 ...
# 6795        6795  ZZ Top            36-22-36
# 6796        6796  ZZ Top     Deal Goin' Down
# 6797        6797  ZZ Top  Can't Stop Rockin'
# 6798        6798  ZZ Top   I Got The Message
# 6799        6799  ZZ Top        Antenna Head
#
#                                                    text  number_of_tokens  \
# 0     sometimes when i'm mad  there's a part of me t...              1551
# 1     tried to sneak out without saying  with my lou...              1029
# 2     you feel bad  let me tell you  we all get the ...              1831
# 3     down in the street they're all singing and sho...              1964
# ...

# %%
tfidf = TfidfVectorizer()
features = tfidf.fit_transform(sample.POS.values.astype(str)) 
labels = sample.Genre1

clusters = KMeans(n_clusters=8, max_iter=300, algorithm = 'auto')
clusters.fit(features)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=8, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
umap = UMAPVisualizer()
umap.fit(features, labels)
umap.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numba\compiler.py:602: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "..\..\..\..\..\ProgramData\Anaconda3\lib\site-packages\umap\sparse.py", line 176:
#     @numba.njit(parallel=True)
#     def nn_descent(
#     ^
#
#   self.func_ir.loc))
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...

# %% [markdown]
# ## Balkendiagramme

# %%
from collections import Counter
import pandas as pd 
df = pd.read_csv("../songs_25.csv")

# %%
df.head(2)
# Out:
#    Unnamed: 0 artists          song  \
# 0           0    ABBA      Me And I
# 1           1    ABBA  My Mama Said
#
#                                                 text  number_of_tokens Genre1  \
# 0  sometimes when i'm mad  there's a part of me t...              1551    Pop
# 1  tried to sneak out without saying  with my lou...              1029    Pop
#
#   Genre2  check                                                POS
# 0   Rock   True  mad little sad mean other rainy gloomy funny d...
# 1   Rock   True  record la la la la red la la la la dead la la ...

# %%
c = Counter(df.artists).most_common()[10:]
sample = df.copy()
for el in c:
    sample = sample[sample.artists!=el[0]]
sample
# Out:
#      Unnamed: 0  artists                         song  \
# 0             0     ABBA                     Me And I
# 1             1     ABBA                 My Mama Said
# 2             2     ABBA            Hole In Your Soul
# 3             3     ABBA                    Cassandra
# 4             4     ABBA                Just A Notion
# ..          ...      ...                          ...
# 245         245  America             Love And Leaving
# 246         246  America                    Hat Trick
# 247         247  America  Till The Sun Comes Up Again
# 248         248  America           Look Up, Look Down
# 249         249  America                 Old Virginia
#
#                                                   text  number_of_tokens  \
# 0    sometimes when i'm mad  there's a part of me t...              1551
# 1    tried to sneak out without saying  with my lou...              1029
# 2    you feel bad  let me tell you  we all get the ...              1831
# ...

# %%
import matplotlib.pyplot as plt
sample.groupby(['Genre1']).artists.count().plot(kind='bar')
plt.savefig('../images/data25/Balkendiagramm_4_haeufigsten_Genre.png', bbox_inches = "tight")

# %%
df.groupby(['Genre1']).artists.count().plot(kind='bar')
plt.savefig('../images/data25/Balkendiagramm_Genre1.png', bbox_inches = "tight")

# %%
df.groupby(['Genre2']).artists.count().plot(kind='bar')
plt.savefig('../images/data25/Balkendiagramm_Genre2.png', bbox_inches = "tight")

# %% [markdown]
# ## UMAP

# %%
import umap
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

# %%
df = pd.read_csv("../songs_25.csv")

# %%
df.head(2)
# Out:
#    Unnamed: 0 artists          song  \
# 0           0    ABBA      Me And I
# 1           1    ABBA  My Mama Said
#
#                                                 text  number_of_tokens Genre1  \
# 0  sometimes when i'm mad  there's a part of me t...              1551    Pop
# 1  tried to sneak out without saying  with my lou...              1029    Pop
#
#   Genre2  check                                                POS  \
# 0   Rock   True  mad little sad mean other rainy gloomy funny d...
# 1   Rock   True  record la la la la red la la la la dead la la ...
#
#                                         stemmed_text
# 0   sometim when i 'm mad there 's a part of me t...
# 1   tri to sneak out without say with my loudest ...

# %%
tfidf = TfidfVectorizer()
data = tfidf.fit_transform(df.text)

# %%
reducer = umap.UMAP(n_components=2, n_neighbors=7)
Xru = reducer.fit_transform(data)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numba\compiler.py:602: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "..\..\..\..\..\ProgramData\Anaconda3\lib\site-packages\umap\sparse.py", line 176:
#     @numba.njit(parallel=True)
#     def nn_descent(
#     ^
#
#   self.func_ir.loc))

# %%
plt.figure(figsize=(12,12))
plt.scatter(Xru[:,0], Xru[:,1], s=10, marker='x')
plt.show()

# %% [markdown]
# ## UMAP 1.0 ohne KMeans

# %%
import pandas as pd

df = pd.read_csv("../songs_25.csv")

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from yellowbrick.text import UMAPVisualizer

tfidf = TfidfVectorizer()
docs = tfidf.fit_transform(df.text)
#labels = corpus.target

# Instantiate the text visualizer
umap = UMAPVisualizer()
umap.fit(docs)
umap.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numba\compiler.py:602: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "..\..\..\..\..\ProgramData\Anaconda3\lib\site-packages\umap\sparse.py", line 176:
#     @numba.njit(parallel=True)
#     def nn_descent(
#     ^
#
#   self.func_ir.loc))
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# ## UMAP 2.0 mit KMeans

# %%
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer

from yellowbrick.text import UMAPVisualizer

tfidf = TfidfVectorizer()
docs = tfidf.fit_transform(df.text)

# Instantiate the clustering model
clusters = KMeans(n_clusters = 5, n_init = 20, max_iter = 600, algorithm = 'auto')
clusters.fit(docs)

umap = UMAPVisualizer()
umap.fit(docs, ["c{}".format(c) for c in clusters.labels_])
umap.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numba\compiler.py:602: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "..\..\..\..\..\ProgramData\Anaconda3\lib\site-packages\umap\sparse.py", line 176:
#     @numba.njit(parallel=True)
#     def nn_descent(
#     ^
#
#   self.func_ir.loc))
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...
