# %% [markdown]
# # Gaussian Mixture Model

# %%
import pandas as pd
import numpy as np

from sklearn import cluster, datasets, mixture
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import normalize
from sklearn.mixture import GaussianMixture
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

from scipy.stats import multivariate_normal

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# import and prepare data

# %%
songs = pd.read_csv('../../songs_longtexts.csv')
songs.head(2)
# Out:
#    Unnamed: 0              song artist                                   link  \
# 0           0  Andante, Andante   ABBA  /a/abba/andante+andante_20002708.html
# 1           1    As Good As New   ABBA   /a/abba/as+good+as+new_20003033.html
#
#                                                 text  \
# 0  take it easy with me  please  touch me gently ...
# 1  i'll never know why i had to go  why i had to ...
#
#                                         stemmed_text  \
# 0   take it easi with me pleas touch me gentli li...
# 1   i 'll never know whi i had to go whi i had to...
#
#                                                  POS  \
# 0  easy slow andante soft light andante strong st...
# 1  lousy rotten tough enough good new good new ne...
#
#                                             POS_tags Genre1 Genre2   genre1  \
# 0  ['VB', 'PRP', 'JJ', 'IN', 'PRP', '_SP', 'UH', ...    Pop   Rock  europop
# 1  ['PRP', 'MD', 'RB', 'VB', 'WRB', 'PRP', 'VBD',...    Pop   Rock  europop
#
#         genre2  number_of_tokens  number_of_types  date decades
# 0  swedish pop             260.0             87.0  1980   1980s
# 1  swedish pop             312.0            120.0  1979   1970s

# %%
# def pdf(data, mean: float, variance: float):
#     # A normal continuous random variable.
#     s1 = 1/(np.sqrt(2*np.pi*variance))
#     s2 = np.exp(-(np.square(data - mean)/(2*variance)))
#     return s1 * s2

# %%
data = songs[(songs.Genre1=='HipHop')|(songs.Genre1=='Electronic')]
data.head(1)
# Out:
#      Unnamed: 0           song      artist  \
# 154         356  Forever Young  Alphaville
#
#                                           link  \
# 154  /a/alphaville/forever+young_20006842.html
#
#                                                   text  \
# 154  let's start in style  let's dance for a while ...
#
#                                           stemmed_text  \
# 154   let 's start in style let 's danc for a while...
#
#                                                    POS  \
# 154  young sandpit short sad golden young young you...
#
#                                               POS_tags      Genre1 Genre2  \
# 154  ['VB', 'PRP', 'VB', 'IN', 'NN', '_SP', 'VB', '...  Electronic    Pop
#
#          genre1   genre2  number_of_tokens  number_of_types  date decades
# 154  dance rock  europop             283.0            135.0  1984   1980s

# %%
tf_idf_vectorizor = TfidfVectorizer()
tf_idf = tf_idf_vectorizor.fit_transform(data.POS.values.astype(str))
tf_idf_norm = normalize(tf_idf)
tf_idf_array = tf_idf_norm.toarray()

# %% [markdown]
# #### BIC und AIC

# %% [markdown]
# Die Wahl der Anzahl der Komponenten misst wie gut GMM als density estimator funktioniert, nicht wie gut es als Clustering Algorithmus funktioniert.

# %%
n_components = np.arange(1, 5)
models = [GaussianMixture(n, n_init=10, covariance_type='full', random_state=0).fit(tf_idf_array)
          for n in n_components]

plt.plot(n_components, [m.bic(tf_idf_array) for m in models], label='BIC')
plt.legend(loc='best')
plt.xlabel('n_components')
# Out:
# Text(0.5, 0, 'n_components')

# %%
plt.plot(n_components, [m.aic(tf_idf_array) for m in models], label='AIC')
plt.legend(loc='best')
plt.xlabel('n_components')
# Out:
# Text(0.5, 0, 'n_components')

# %%
def compute_PCA(text):
    pca = PCA(n_components = 2)
    Y = pca.fit_transform(text)
    return Y

# %%
def plot_PCA(Y, prediction):
    plt.figure(figsize=(15,10))
    plt.scatter(Y[:, 0], Y[:, 1], c=prediction, s=50, cmap='viridis')
    plt.title('PCA')
#     plt.savefig('K_Means/PCA_after_kmeans.png', bbox_inches = "tight")

# %% [markdown]
# #### hard clustering

# %%
gmm = GaussianMixture(n_components=2, n_init=10, covariance_type='full').fit(tf_idf_array)
prediction = gmm.predict(tf_idf_array)
Y = compute_PCA(tf_idf_array)
sns.scatterplot(Y[:, 0], Y[:, 1],hue=prediction, palette=sns.color_palette("hls", len(np.unique(prediction))))

# %%
print(gmm.means_)
print('\n')
print(gmm.covariances_)
# Out:
# [[0.00021137 0.00044439 0.00010443 ... 0.00028635 0.00027028 0.00153652]
#  [0.         0.         0.         ... 0.         0.         0.0008699 ]]
#
#
# [[[ 2.16414432e-05 -9.39320834e-08 -2.20741218e-08 ... -6.05256012e-08
#    -5.71307473e-08 -3.24778303e-07]
#   [-9.39320834e-08  9.22371691e-05 -4.64086897e-08 ... -1.27249177e-07
#    -1.20111828e-07 -6.82814726e-07]
#   [-2.20741218e-08 -4.64086897e-08  6.03861021e-06 ... -2.99036680e-08
#    -2.82263847e-08 -1.60462058e-07]
#   ...
#   [-6.05256012e-08 -1.27249177e-07 -2.99036680e-08 ...  3.88810593e-05
#    -7.73946485e-08 -4.39975036e-07]
#   [-5.71307473e-08 -1.20111828e-07 -2.82263847e-08 ... -7.73946485e-08
#     3.47507712e-05 -4.15297033e-07]
#   [-3.24778303e-07 -6.82814726e-07 -1.60462058e-07 ... -4.39975036e-07
#    -4.15297033e-07  2.76980497e-04]]
#
#  [[ 1.00000000e-06  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#     0.00000000e+00  0.00000000e+00]
#   [ 0.00000000e+00  1.00000000e-06  0.00000000e+00 ...  0.00000000e+00
#     0.00000000e+00  0.00000000e+00]
#   [ 0.00000000e+00  0.00000000e+00  1.00000000e-06 ...  0.00000000e+00
#     0.00000000e+00  0.00000000e+00]
#   ...
#   [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  1.00000000e-06
#     0.00000000e+00  0.00000000e+00]
#   [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#     1.00000000e-06  0.00000000e+00]
#   [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#     0.00000000e+00  1.24346585e-04]]]

# %% [markdown]
# #### soft clustering

# %%
probs = gmm.predict_proba(tf_idf_array)
print(probs[:5].round(3))
# Out:
# [[1. 0.]
#  [1. 0.]
#  [1. 0.]
#  [1. 0.]
#  [0. 1.]]

# %% [markdown]
# visualisieren mit PCA

# %%
size = 50 * probs.max(1) ** 2  # square emphasizes differences
sns.scatterplot(Y[:, 0], Y[:, 1],hue=prediction, palette=sns.color_palette("hls", len(np.unique(prediction))), size=size)

# %% [markdown]
# visualisieren mit T-SNE

# %%
def visualize_tsne(X_embedded, hue):
    fig = plt.figure(figsize=(8, 8))
    ax = plt.axes(frameon=False)
    plt.setp(ax, xticks=(), yticks=())
    plt.subplots_adjust(left=0.0, bottom=0.0, right=1.0, top=0.9,
                    wspace=0.0, hspace=0.0)
    num = len(np.unique(hue))
    sns.scatterplot(X_embedded[:, 0], X_embedded[:, 1],hue=hue, marker="o", palette=sns.color_palette("hls", num), legend=False)
    plt.title("Songtexte")
#     plt.savefig(figname)
    plt.show()

# %%
# perplexity = [2,5,10,30,40,50,100]

perplexity = [50]
for p in perplexity:
    X_embedded = TSNE(n_components=2, perplexity=p, early_exaggeration=30,learning_rate=50, verbose=2).fit_transform(tf_idf_array)
    figname = "tsne_songtextegekuerzt_perplexity"+str(p)
    visualize_tsne(X_embedded, prediction)
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 627 samples in 0.192s...
# [t-SNE] Computed neighbors for 627 samples in 3.402s...
# [t-SNE] Computed conditional probabilities for sample 627 / 627
# [t-SNE] Mean sigma: 0.312530
# [t-SNE] Computed conditional probabilities in 0.049s
# [t-SNE] Iteration 50: error = 186.8195496, gradient norm = 0.9498806 (50 iterations in 0.146s)
# [t-SNE] Iteration 100: error = 183.0071106, gradient norm = 1.0135710 (50 iterations in 0.178s)
# [t-SNE] Iteration 150: error = 182.5958557, gradient norm = 0.9859668 (50 iterations in 0.149s)
# [t-SNE] Iteration 200: error = 183.3697815, gradient norm = 0.9279584 (50 iterations in 0.162s)
# [t-SNE] Iteration 250: error = 189.0982361, gradient norm = 0.9174013 (50 iterations in 0.235s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 189.098236
# [t-SNE] Iteration 300: error = 1.6789508, gradient norm = 0.0041260 (50 iterations in 0.155s)
# [t-SNE] Iteration 350: error = 1.5754222, gradient norm = 0.0009590 (50 iterations in 0.217s)
# [t-SNE] Iteration 400: error = 1.5344883, gradient norm = 0.0005535 (50 iterations in 0.147s)
# [t-SNE] Iteration 450: error = 1.5162139, gradient norm = 0.0004116 (50 iterations in 0.146s)
# [t-SNE] Iteration 500: error = 1.5070391, gradient norm = 0.0003219 (50 iterations in 0.145s)
# [t-SNE] Iteration 550: error = 1.5015055, gradient norm = 0.0002857 (50 iterations in 0.135s)
# [t-SNE] Iteration 600: error = 1.4987192, gradient norm = 0.0002127 (50 iterations in 0.120s)
# [t-SNE] Iteration 650: error = 1.4965827, gradient norm = 0.0001688 (50 iterations in 0.151s)
# [t-SNE] Iteration 700: error = 1.4947863, gradient norm = 0.0001563 (50 iterations in 0.125s)
# [t-SNE] Iteration 750: error = 1.4925951, gradient norm = 0.0001573 (50 iterations in 0.163s)
# [t-SNE] Iteration 800: error = 1.4919199, gradient norm = 0.0001378 (50 iterations in 0.135s)
# [t-SNE] Iteration 850: error = 1.4912937, gradient norm = 0.0000761 (50 iterations in 0.191s)
# [t-SNE] Iteration 900: error = 1.4905107, gradient norm = 0.0000891 (50 iterations in 0.251s)
# [t-SNE] Iteration 950: error = 1.4899664, gradient norm = 0.0000989 (50 iterations in 0.337s)
# [t-SNE] Iteration 1000: error = 1.4889522, gradient norm = 0.0001223 (50 iterations in 0.136s)
# [t-SNE] KL divergence after 1000 iterations: 1.488952
