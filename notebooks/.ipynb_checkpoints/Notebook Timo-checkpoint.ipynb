# %%
import pandas as pd
df = pd.read_csv("../sample_25percent.csv")

# %%
df
# Out:
#        Unnamed: 0              artist                          song  \
# 0           20468           Van Halen        Take Your Whiskey Home
# 1           41605           Lil Wayne                     Army Gunz
# 2           52292       Stevie Wonder              Isn't She Lovely
# 3           42697        Mariah Carey                  O Holy Night
# 4           27993               Clash  I'm So Bored With The U.S.A.
# ...           ...                 ...                           ...
# 12703       25325      Billie Holiday                My Last Affair
# 12704       28783  Dave Matthews Band             The Space Between
# 12705       18645             Squeeze            Crying In My Sleep
# 12706       32684        Foo Fighters                    Dear Lover
# 12707        9201          Jason Mraz              Kickin' With You
#
#                                                     text  number_of_tokens
# 0      well  my baby  she don't want me around.  she ...              1197
# ...

# %%
df.shape
# Out:
# (12708, 5)

# %%
df.text
# Out:
# 0        well  my baby  she don't want me around.  she ...
# 1          yeah yeah yeah (i got army gunz)  yeah yeah ...
# 2        isn't she lovely  isn't she wonderful  isn't s...
# 3        o holy night the stars are brightly shining  i...
# 4        yankee soldier  he want to shoot some skag  he...
#                                ...
# 12703    can't you see  what love and romance have done...
# 12704    you cannot quit me so quickly  is no hope in y...
# 12705    breaking up  is breaking my heart  is showing ...
# 12706    dear lover  do you remember?  the sound of you...
# 12707    ahhhh oh kickin' with you  wooh  huh  yeah  uh...
# Name: text, Length: 12708, dtype: object

# %%
df.artist.dropna()
# Out:
# 0                 Van Halen
# 1                 Lil Wayne
# 2             Stevie Wonder
# 3              Mariah Carey
# 4                     Clash
#                 ...
# 12703        Billie Holiday
# 12704    Dave Matthews Band
# 12705               Squeeze
# 12706          Foo Fighters
# 12707            Jason Mraz
# Name: artist, Length: 12708, dtype: object

# %%
a = df.artist.unique()

# %%
a.shape
# Out:
# (415,)

# %%
df.groupby('artist').song.count().plot(kind='bar').set_xlabel('Bands')
# Out:
# Text(0.5, 0, 'Bands')

# %% [markdown]
# # UMAP

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
corpus = pd.read_csv("../sample_25percent.csv")
corpus.head(2)
# Out:
#    Unnamed: 0     artist                    song  \
# 0       20468  Van Halen  Take Your Whiskey Home
# 1       41605  Lil Wayne               Army Gunz
#
#                                                 text  number_of_tokens
# 0  well  my baby  she don't want me around.  she ...              1197
# 1    yeah yeah yeah (i got army gunz)  yeah yeah ...              2860

# %%
labels = LabelEncoder().fit_transform(corpus["artist"])
labels = labels.reshape(labels.shape[0])
features = TfidfVectorizer().fit_transform(corpus["song"])
cluster = KMeans(n_clusters=3, random_state=0, n_jobs=-1)
model = cluster.fit(features)

# %%
from yellowbrick.text import UMAPVisualizer

# %%
umap = UMAPVisualizer()
umap.fit(features, corpus["artist"])
umap.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\umap\sparse.py:247: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "..\..\..\..\..\ProgramData\Anaconda3\lib\site-packages\umap\utils.py", line 409:
# @numba.njit(parallel=True)
# def build_candidates(current_graph, n_vertices, n_neighbors, max_candidates, rng_state):
# ^
#
#   current_graph, n_vertices, n_neighbors, max_candidates, rng_state
# C:\ProgramData\Anaconda3\lib\site-packages\numba\compiler.py:602: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# ...
