# %%
import pandas as pd
import numpy as np
from collections import Counter
import regex as re

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE
from yellowbrick.text import TSNEVisualizer
# Out:
# /home/teresa/.local/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
songs = pd.read_csv("../songtexte_bereinigt_gekuerzt.csv")
songs
# Out:
#        Unnamed: 0        artist                   song  \
# 0               0          ABBA  Ahe's My Kind Of Girl
# 1               1          ABBA       Andante, Andante
# 2               2          ABBA         As Good As New
# 3               3          ABBA                   Bang
# 4               4          ABBA       Bang-A-Boomerang
# ...           ...           ...                    ...
# 50827       57642  Ziggy Marley                 Friend
# 50828       57643  Ziggy Marley                     G7
# 50829       57644  Ziggy Marley             Generation
# 50830       57645  Ziggy Marley          Good Old Days
# 50831       57646  Ziggy Marley          Hand To Mouth
#
#                                                     text  number_of_tokens
# 0      look at her face  it's a wonderful face  and i...               741
# 1      take it easy with me  please  touch me gently ...              1381
# 2      i'll never know why i had to go  why i had to ...              1438
# 3      making somebody happy is a question of give an...              1207
# 4      making somebody happy is a question of give an...              1223
# ...                                                  ...               ...
# 50827    i wanna thank you for the things you've done...               691
# 50828  seven richest countries in the world  them hav...              1443
# 50829  many generation have passed away  fighting for...              1391
# 50830  irie days come on play  let the angels fly let...               858
# 50831  power to the workers  more power  power to the...              2867
#
# [50832 rows x 5 columns]

# %%
len(np.unique(songs.Genre2))
# Out:
# 10

# %%
c = Counter(songs.artists).most_common()[10:]

# %%
sample = songs.copy()
for el in c:
    sample = sample[sample.artists!=el[0]]
sample
# Out:
#      Unnamed: 0  artists                         song  \
# 0             0     ABBA                     Me And I
# 1             1     ABBA                 My Mama Said
# 2             2     ABBA            Hole In Your Soul
# 3             3     ABBA                    Cassandra
# 4             4     ABBA                Just A Notion
# ..          ...      ...                          ...
# 245         245  America             Love And Leaving
# 246         246  America                    Hat Trick
# 247         247  America  Till The Sun Comes Up Again
# 248         248  America           Look Up, Look Down
# 249         249  America                 Old Virginia
#
#                                                   text  number_of_tokens  \
# 0    sometimes when i'm mad  there's a part of me t...              1551
# 1    tried to sneak out without saying  with my lou...              1029
# 2    you feel bad  let me tell you  we all get the ...              1831
# 3    down in the street they're all singing and sho...              1964
# 4    just a notion that's all  just a feeling that ...               514
# ..                                                 ...               ...
# 245  (gerry beckley and bill mumy)    hey slim how ...              1046
# 246  you  can i make it known  i'd like to take you...              1773
# 247  think i'll write a different song  got a feeli...               706
# 248  author unknown (sung by gerry beckley)  found ...               880
# 249  hey  honey  won't you sit down  and stop here ...              1156
#
#     Genre1 Genre2  check                                                POS  \
# 0      Pop   Rock   True  mad little sad mean other rainy gloomy funny d...
# 1      Pop   Rock   True  record la la la la red la la la la dead la la ...
# 2      Pop   Rock   True  bad bad bad sad loose cool bright romantic bad...
# 3      Pop   Rock   True  alive dead hollow smart sorry last sorry final...
# 4      Pop   Rock   True  mistaking right wrong special notion feeling m...
# ..     ...    ...    ...                                                ...
# 245   Rock    Pop   True  first close new cool clear concealing revealin...
# 246   Rock    Pop   True  known local little little worthwhile little wo...
# 247   Rock    Pop   True  different long bad song feeling time singin se...
# 248   Rock    Pop   True  second second whole wide second second tired a...
# 249   Rock    Pop   True  sweet old whole sure pleased old poor changed ...
#
#      length
# 0     large
# 1    medium
# 2     large
# 3     large
# 4     short
# ..      ...
# 245  medium
# 246   large
# 247   short
# 248   short
# 249  medium
#
# [250 rows x 10 columns]

# %%
sample = songs.sample(frac=.25)
sample
# Out:
#       Unnamed: 0          artists                      song  \
# 6285        6285             UB40            Maybe Tomorrow
# 2861        2861     Janis Joplin             See See Rider
# 6283        6283             UB40  Everything Is Better Now
# 1905        1905       Eurythmics      Peace Is Just A Word
# 1065        1065  Christmas Songs     Home On Christmas Day
# ...          ...              ...                       ...
# 346          346    Avril Lavigne                   Take It
# 4159        4159        Metallica   That Was Just Your Life
# 6704        6704              XTC    Life Begins At The Hop
# 5657        5657      Rod Stewart         Hotel Chambermaid
# 1079        1079      Chuck Berry           I Need You Baby
#
#                                                    text  number_of_tokens  \
# 6285  i don't know how many stars there are  up in t...              1388
# 2861  and it's hey  hey hey  she was standin' in the...               795
# 6283  everything is better now  better than is was b...               747
# 1905  stop the world  turn out the sun  i'm so tired...               996
# 1065  and now that winter's here  soon it will be ch...              1215
# ...                                                 ...               ...
# 346   just take it take it.  just take it take it.  ...              1257
# 4159  like a siren in my head that i was placed to r...              2124
# 6704  i have learnt there's a magical spot at the ho...               593
# 5657  when the lights are low you know i'm going to ...              1087
# 1079  please  listen  baby  try and understand  as s...               800
#
#           Genre1       Genre2  check  \
# 6285      Reggae          Pop   True
# 2861        Rock        Blues   True
# 6283      Reggae          Pop   True
# 1905  Electronic          Pop   True
# 1065         Pop         Rock   True
# ...          ...          ...    ...
# 346         Rock          Pop   True
# 4159        Rock   Electronic   True
# 6704  Electronic         Rock   True
# 5657        Rock          Pop   True
# 1079        Rock          Pop   True
#
#                                                     POS  length
# 6285  many heavenly beautiful sky heaven earth time ...  medium
# 2861  good bad good bad good bad kitchen honey morni...   short
# 6283  golden closed clean fresh open safe serial bad...   short
# 1905  tired little world sun world day way peace wor...   short
# 1065  clear high frosted bright silent safe warm ast...  medium
# ...                                                 ...     ...
# 346   alone true worried fictional true sorry true s...  medium
# 4159  blind astray about endless present endless hot...   large
# 6704  magical good cheap young next ridiculous spot ...   short
# 5657  low dead hotel garden night river rolling wind...  medium
# 1079  sure true hard other baby woman man baby love ...   short
#
# [1700 rows x 10 columns]

# %%
def visualize_tsne(X_embedded, hue, figname):
    fig = plt.figure(figsize=(8, 8))
    ax = plt.axes(frameon=False)
    plt.setp(ax, xticks=(), yticks=())
    plt.subplots_adjust(left=0.0, bottom=0.0, right=1.0, top=0.9,
                    wspace=0.0, hspace=0.0)
    num = len(np.unique(hue))
    sns.scatterplot(X_embedded[:, 0], X_embedded[:, 1],hue=hue, marker="o", palette=sns.color_palette("hls", num), legend=False)
    plt.title("Songtexte")
    plt.savefig(figname)
    plt.show()

# %%
part = songs.copy()
part = part[part.Genre1!="Rock"]

# %%
data = TfidfVectorizer().fit_transform(songs.text)

# data = TfidfVectorizer().fit_transform(sample.POS.values.astype(str))

X_reduced = TruncatedSVD(n_components=10, random_state=0).fit_transform(data)

# %%
# perplexity = [2,5,10,30,40,50,100]

perplexity = [50]
for p in perplexity:
    X_embedded = TSNE(n_components=2, perplexity=p, n_iter=1000,learning_rate=10, verbose=2).fit_transform(X_reduced)
    figname = "tsne_songtextegekuerzt_perplexity"+str(p)
    visualize_tsne(X_embedded, songs.artist, figname)
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 50832 samples in 0.235s...
# [t-SNE] Computed neighbors for 50832 samples in 114.040s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 50832
# [t-SNE] Computed conditional probabilities for sample 2000 / 50832
# [t-SNE] Computed conditional probabilities for sample 3000 / 50832
# [t-SNE] Computed conditional probabilities for sample 4000 / 50832
# [t-SNE] Computed conditional probabilities for sample 5000 / 50832
# [t-SNE] Computed conditional probabilities for sample 6000 / 50832
# [t-SNE] Computed conditional probabilities for sample 7000 / 50832
# [t-SNE] Computed conditional probabilities for sample 8000 / 50832
# [t-SNE] Computed conditional probabilities for sample 9000 / 50832
# [t-SNE] Computed conditional probabilities for sample 10000 / 50832
# [t-SNE] Computed conditional probabilities for sample 11000 / 50832
# [t-SNE] Computed conditional probabilities for sample 12000 / 50832
# [t-SNE] Computed conditional probabilities for sample 13000 / 50832
# [t-SNE] Computed conditional probabilities for sample 14000 / 50832
# [t-SNE] Computed conditional probabilities for sample 15000 / 50832
# [t-SNE] Computed conditional probabilities for sample 16000 / 50832
# [t-SNE] Computed conditional probabilities for sample 17000 / 50832
# [t-SNE] Computed conditional probabilities for sample 18000 / 50832
# [t-SNE] Computed conditional probabilities for sample 19000 / 50832
# [t-SNE] Computed conditional probabilities for sample 20000 / 50832
# [t-SNE] Computed conditional probabilities for sample 21000 / 50832
# [t-SNE] Computed conditional probabilities for sample 22000 / 50832
# [t-SNE] Computed conditional probabilities for sample 23000 / 50832
# [t-SNE] Computed conditional probabilities for sample 24000 / 50832
# [t-SNE] Computed conditional probabilities for sample 25000 / 50832
# [t-SNE] Computed conditional probabilities for sample 26000 / 50832
# [t-SNE] Computed conditional probabilities for sample 27000 / 50832
# [t-SNE] Computed conditional probabilities for sample 28000 / 50832
# [t-SNE] Computed conditional probabilities for sample 29000 / 50832
# [t-SNE] Computed conditional probabilities for sample 30000 / 50832
# [t-SNE] Computed conditional probabilities for sample 31000 / 50832
# [t-SNE] Computed conditional probabilities for sample 32000 / 50832
# [t-SNE] Computed conditional probabilities for sample 33000 / 50832
# [t-SNE] Computed conditional probabilities for sample 34000 / 50832
# [t-SNE] Computed conditional probabilities for sample 35000 / 50832
# [t-SNE] Computed conditional probabilities for sample 36000 / 50832
# [t-SNE] Computed conditional probabilities for sample 37000 / 50832
# [t-SNE] Computed conditional probabilities for sample 38000 / 50832
# [t-SNE] Computed conditional probabilities for sample 39000 / 50832
# [t-SNE] Computed conditional probabilities for sample 40000 / 50832
# [t-SNE] Computed conditional probabilities for sample 41000 / 50832
# [t-SNE] Computed conditional probabilities for sample 42000 / 50832
# [t-SNE] Computed conditional probabilities for sample 43000 / 50832
# [t-SNE] Computed conditional probabilities for sample 44000 / 50832
# [t-SNE] Computed conditional probabilities for sample 45000 / 50832
# [t-SNE] Computed conditional probabilities for sample 46000 / 50832
# [t-SNE] Computed conditional probabilities for sample 47000 / 50832
# [t-SNE] Computed conditional probabilities for sample 48000 / 50832
# [t-SNE] Computed conditional probabilities for sample 49000 / 50832
# [t-SNE] Computed conditional probabilities for sample 50000 / 50832
# [t-SNE] Computed conditional probabilities for sample 50832 / 50832
# [t-SNE] Mean sigma: 0.038007
# [t-SNE] Computed conditional probabilities in 6.694s
# [t-SNE] Iteration 50: error = 110.1642838, gradient norm = 0.0000005 (50 iterations in 56.201s)
# [t-SNE] Iteration 100: error = 110.1642838, gradient norm = 0.0000001 (50 iterations in 52.726s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 100 iterations with early exaggeration: 110.164284
# [t-SNE] Iteration 150: error = 6.6985903, gradient norm = 0.0000002 (50 iterations in 55.966s)
# [t-SNE] Iteration 200: error = 6.6985903, gradient norm = 0.0000019 (50 iterations in 66.103s)
# [t-SNE] Iteration 250: error = 6.6985607, gradient norm = 0.0000654 (50 iterations in 73.072s)
# [t-SNE] Iteration 300: error = 6.5710640, gradient norm = 0.0030281 (50 iterations in 67.775s)
# [t-SNE] Iteration 350: error = 5.6063352, gradient norm = 0.0021124 (50 iterations in 55.121s)
# [t-SNE] Iteration 400: error = 5.2335243, gradient norm = 0.0013729 (50 iterations in 51.311s)
# [t-SNE] Iteration 450: error = 5.0153017, gradient norm = 0.0010763 (50 iterations in 46.770s)
# [t-SNE] Iteration 500: error = 4.8536739, gradient norm = 0.0008999 (50 iterations in 53.820s)
# [t-SNE] Iteration 550: error = 4.7238240, gradient norm = 0.0007732 (50 iterations in 52.225s)
# [t-SNE] Iteration 600: error = 4.6154251, gradient norm = 0.0006774 (50 iterations in 50.375s)
# [t-SNE] Iteration 650: error = 4.5223932, gradient norm = 0.0005992 (50 iterations in 58.057s)
# [t-SNE] Iteration 700: error = 4.4417672, gradient norm = 0.0005358 (50 iterations in 60.014s)
# [t-SNE] Iteration 750: error = 4.3703508, gradient norm = 0.0004868 (50 iterations in 59.100s)
# [t-SNE] Iteration 800: error = 4.3064256, gradient norm = 0.0004456 (50 iterations in 57.269s)
# [t-SNE] Iteration 850: error = 4.2486253, gradient norm = 0.0004121 (50 iterations in 54.990s)
# [t-SNE] Iteration 900: error = 4.1962771, gradient norm = 0.0003781 (50 iterations in 52.423s)
# [t-SNE] Iteration 950: error = 4.1492295, gradient norm = 0.0003488 (50 iterations in 55.185s)
# [t-SNE] Iteration 1000: error = 4.1065822, gradient norm = 0.0003230 (50 iterations in 55.290s)
# [t-SNE] KL divergence after 1000 iterations: 4.106582

# %%
songs['length']="0"

for i, row in songs.iterrows():
    if row.number_of_tokens >1500:
        songs.at[i, 'length'] = "large"
    elif row.number_of_tokens >=1000 and row.number_of_tokens<1500:
        songs.at[i, 'length'] = "medium"
    elif row.number_of_tokens < 1000:
        songs.at[i, 'length'] = "short"
songs
# Out:
#       Unnamed: 0 artists                song  \
# 0              0    ABBA            Me And I
# 1              1    ABBA        My Mama Said
# 2              2    ABBA   Hole In Your Soul
# 3              3    ABBA           Cassandra
# 4              4    ABBA       Just A Notion
# ...          ...     ...                 ...
# 6795        6795  ZZ Top            36-22-36
# 6796        6796  ZZ Top     Deal Goin' Down
# 6797        6797  ZZ Top  Can't Stop Rockin'
# 6798        6798  ZZ Top   I Got The Message
# 6799        6799  ZZ Top        Antenna Head
#
#                                                    text  number_of_tokens  \
# 0     sometimes when i'm mad  there's a part of me t...              1551
# 1     tried to sneak out without saying  with my lou...              1029
# 2     you feel bad  let me tell you  we all get the ...              1831
# 3     down in the street they're all singing and sho...              1964
# 4     just a notion that's all  just a feeling that ...               514
# ...                                                 ...               ...
# 6795  what  what  what you want? hey  my thing is a ...               646
# 6796  when the deal goin' down and you gonna take yo...               746
# 6797  i heard about the rock for sometime  i know.  ...               995
# 6798  i'm picking up on a signal  that's in the air ...               495
# 6799  old 61's my number on the hi-way  i'm turnin' ...               556
#
#      Genre1 Genre2  check                                                POS  \
# 0       Pop   Rock   True  mad little sad mean other rainy gloomy funny d...
# 1       Pop   Rock   True  record la la la la red la la la la dead la la ...
# 2       Pop   Rock   True  bad bad bad sad loose cool bright romantic bad...
# 3       Pop   Rock   True  alive dead hollow smart sorry last sorry final...
# 4       Pop   Rock   True  mistaking right wrong special notion feeling m...
# ...     ...    ...    ...                                                ...
# 6795   Rock    Pop   True  real fine real fine round thing thing thing th...
# 6796   Rock    Pop   True  deal chance mystery trance future deal deal no...
# 6797   Rock    Pop   True  easy wrong right low loose high rock roll rock...
# 6798   Rock    Pop   True  straight electric about empty straight straigh...
# 6799   Rock    Pop   True  bad only only red full number hi way v ass way...
#
#       length
# 0      large
# 1     medium
# 2      large
# 3      large
# 4      short
# ...      ...
# 6795   short
# 6796   short
# 6797   short
# 6798   short
# 6799   short
#
# [6800 rows x 10 columns]
