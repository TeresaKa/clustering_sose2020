# %% [markdown]
# **Notebook beinhaltet**:
# preprocessing des Datensatzes:
# + entferne Satzzeichen, "chorus", nur Kleinbuchstaben
# + füge Spalte mit Songlänge/ Anzahl der Token hinzu
# + erstelle ein Sample aus 25% des Originaldatensatzes
# + Stemming der Songtexte

# %%
import pandas as pd
import numpy as np
from collections import Counter

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# load raw data

# %%
songs = pd.read_csv("songs_plus_dates.csv")
songs
# Out:
#        Unnamed: 0              song  date artist  \
# 0               0  Andante, Andante  1980   ABBA
# 1               1    As Good As New  1979   ABBA
# 2               2  Bang-A-Boomerang  1975   ABBA
# 3               3         Cassandra  1981   ABBA
# 4               4        Chiquitita  1979   ABBA
# ...           ...               ...   ...    ...
# 15947       15947     Vampire Heart  2005    HIM
# 15948       15948        Venus Doom  2007    HIM
# 15949       15949       Wicked Game  2012    HIM
# 15950       15950   You Are The One  2014    HIM
# 15951       15951    Your Sweet 666  2014    HIM
#
#                                                     text Genre1 Genre2  \
# 0      Take it easy with me, please  \nTouch me gentl...    Pop   Rock
# 1      I'll never know why I had to go  \nWhy I had t...    Pop   Rock
# 2      Making somebody happy is a question of give an...    Pop   Rock
# 3      Down in the street they're all singing and sho...    Pop   Rock
# 4      Chiquitita, tell me what's wrong  \nYou're enc...    Pop   Rock
# ...                                                  ...    ...    ...
# 15947  You can't escape the wrath of my heart  \nBeat...   Rock    Pop
# 15948  Leave all behind now to watch her crawl  \nThr...   Rock    Pop
# 15949  The world was on fire  \nNo one could save me ...   Rock    Pop
# 15950  No I won't surrender  \nAt any cost  \nYou're ...   Rock    Pop
# 15951  There are things you should know  \nThe distan...   Rock    Pop
#
#        number_of_tokens                                       stemmed_text  \
# 0                  1434   take it easi with me , pleas touch me gentli ...
# 1                  1477   I 'll never know whi I had to go whi I had to...
# 2                  1263   make somebodi happi is a question of give and...
# 3                  2028   down in the street they 're all sing and shou...
# 4                  1591   chiquitita , tell me what 's wrong you 're en...
# ...                 ...                                                ...
# 15947               674   you ca n't escap the wrath of my heart beat t...
# 15948               901   leav all behind now to watch her crawl throug...
# 15949              1384   the world wa on fire No one could save me but...
# 15950               608   No I wo n't surrend At ani cost you 're somet...
# 15951               921   there are thing you should know the distanc b...
#
#                                                      POS
# 0      easy slow soft light strong strong strong stro...
# 1      lousy rotten tough enough good new good new ne...
# 2      happy little Sweet sweet tender Dumb dumb dumb...
# 3      alive dead hollow smart last final slow thorou...
# 4      wrong own sad quiet sure new new hard sad quie...
# ...                                                  ...
# 15947  brave dark cold alive vampire wrath heart fune...
# 15948  dark worth tragic ecstatic worth dark infernal...
# 15949  strange foolish wicked wicked wicked wicked st...
# 15950  sweet good true cost something heart evil hone...
# 15951  strong ready sweet true ready sweet late lonel...
#
# [15952 rows x 10 columns]

# %%
songs.drop('Unnamed: 0', axis=1, inplace=True)
songs
# Out:
#                    song  date artist  \
# 0      Andante, Andante  1980   ABBA
# 1        As Good As New  1979   ABBA
# 2      Bang-A-Boomerang  1975   ABBA
# 3             Cassandra  1981   ABBA
# 4            Chiquitita  1979   ABBA
# ...                 ...   ...    ...
# 15947     Vampire Heart  2005    HIM
# 15948        Venus Doom  2007    HIM
# 15949       Wicked Game  2012    HIM
# 15950   You Are The One  2014    HIM
# 15951    Your Sweet 666  2014    HIM
#
#                                                     text Genre1 Genre2  \
# 0      Take it easy with me, please  \nTouch me gentl...    Pop   Rock
# 1      I'll never know why I had to go  \nWhy I had t...    Pop   Rock
# 2      Making somebody happy is a question of give an...    Pop   Rock
# 3      Down in the street they're all singing and sho...    Pop   Rock
# 4      Chiquitita, tell me what's wrong  \nYou're enc...    Pop   Rock
# ...                                                  ...    ...    ...
# 15947  You can't escape the wrath of my heart  \nBeat...   Rock    Pop
# 15948  Leave all behind now to watch her crawl  \nThr...   Rock    Pop
# 15949  The world was on fire  \nNo one could save me ...   Rock    Pop
# 15950  No I won't surrender  \nAt any cost  \nYou're ...   Rock    Pop
# 15951  There are things you should know  \nThe distan...   Rock    Pop
#
#        number_of_tokens                                       stemmed_text  \
# 0                  1434   take it easi with me , pleas touch me gentli ...
# 1                  1477   I 'll never know whi I had to go whi I had to...
# 2                  1263   make somebodi happi is a question of give and...
# 3                  2028   down in the street they 're all sing and shou...
# 4                  1591   chiquitita , tell me what 's wrong you 're en...
# ...                 ...                                                ...
# 15947               674   you ca n't escap the wrath of my heart beat t...
# 15948               901   leav all behind now to watch her crawl throug...
# 15949              1384   the world wa on fire No one could save me but...
# 15950               608   No I wo n't surrend At ani cost you 're somet...
# 15951               921   there are thing you should know the distanc b...
#
#                                                      POS
# 0      easy slow soft light strong strong strong stro...
# 1      lousy rotten tough enough good new good new ne...
# 2      happy little Sweet sweet tender Dumb dumb dumb...
# 3      alive dead hollow smart last final slow thorou...
# 4      wrong own sad quiet sure new new hard sad quie...
# ...                                                  ...
# 15947  brave dark cold alive vampire wrath heart fune...
# 15948  dark worth tragic ecstatic worth dark infernal...
# 15949  strange foolish wicked wicked wicked wicked st...
# 15950  sweet good true cost something heart evil hone...
# 15951  strong ready sweet true ready sweet late lonel...
#
# [15952 rows x 9 columns]

# %%
for i, row in songs.iterrows():
    songs.at[i, 'text'] = row.text.replace(',',' ').replace('(',' ').replace(')',' ').replace('\n', '').replace("[Chorus]", "").lower().split()
songs
# Out:
#                    song  date artist  \
# 0      Andante, Andante  1980   ABBA
# 1        As Good As New  1979   ABBA
# 2      Bang-A-Boomerang  1975   ABBA
# 3             Cassandra  1981   ABBA
# 4            Chiquitita  1979   ABBA
# ...                 ...   ...    ...
# 15947     Vampire Heart  2005    HIM
# 15948        Venus Doom  2007    HIM
# 15949       Wicked Game  2012    HIM
# 15950   You Are The One  2014    HIM
# 15951    Your Sweet 666  2014    HIM
#
#                                                     text Genre1 Genre2  \
# 0      take it easy with me  please  touch me gently ...    Pop   Rock
# 1      i'll never know why i had to go  why i had to ...    Pop   Rock
# 2      making somebody happy is a question of give an...    Pop   Rock
# 3      down in the street they're all singing and sho...    Pop   Rock
# 4      chiquitita  tell me what's wrong  you're encha...    Pop   Rock
# ...                                                  ...    ...    ...
# 15947  you can't escape the wrath of my heart  beatin...   Rock    Pop
# 15948  leave all behind now to watch her crawl  throu...   Rock    Pop
# 15949  the world was on fire  no one could save me bu...   Rock    Pop
# 15950  no i won't surrender  at any cost  you're some...   Rock    Pop
# 15951  there are things you should know  the distance...   Rock    Pop
#
#        number_of_tokens                                       stemmed_text  \
# 0                  1434   take it easi with me , pleas touch me gentli ...
# 1                  1477   I 'll never know whi I had to go whi I had to...
# 2                  1263   make somebodi happi is a question of give and...
# 3                  2028   down in the street they 're all sing and shou...
# 4                  1591   chiquitita , tell me what 's wrong you 're en...
# ...                 ...                                                ...
# 15947               674   you ca n't escap the wrath of my heart beat t...
# 15948               901   leav all behind now to watch her crawl throug...
# 15949              1384   the world wa on fire No one could save me but...
# 15950               608   No I wo n't surrend At ani cost you 're somet...
# 15951               921   there are thing you should know the distanc b...
#
#                                                      POS
# 0      easy slow soft light strong strong strong stro...
# 1      lousy rotten tough enough good new good new ne...
# 2      happy little Sweet sweet tender Dumb dumb dumb...
# 3      alive dead hollow smart last final slow thorou...
# 4      wrong own sad quiet sure new new hard sad quie...
# ...                                                  ...
# 15947  brave dark cold alive vampire wrath heart fune...
# 15948  dark worth tragic ecstatic worth dark infernal...
# 15949  strange foolish wicked wicked wicked wicked st...
# 15950  sweet good true cost something heart evil hone...
# 15951  strong ready sweet true ready sweet late lonel...
#
# [15952 rows x 9 columns]

# %%
songs.to_csv("songs_plus_dates.csv")

# %% [markdown]
# remove artists with less than 60 songs

# %%
c = Counter(songs.artist)

# %%
for v, k in c.items():
    if k<60:
        songs = songs[songs.artist!=v]

# %%
songs['number_of_tokens'] = songs.text.str.len()

# %%
# songs.drop('link', axis=1, inplace=True)
songs
# Out:
#                    song  date artist  \
# 0      Andante, Andante  1980   ABBA
# 1        As Good As New  1979   ABBA
# 2      Bang-A-Boomerang  1975   ABBA
# 3             Cassandra  1981   ABBA
# 4            Chiquitita  1979   ABBA
# ...                 ...   ...    ...
# 15947     Vampire Heart  2005    HIM
# 15948        Venus Doom  2007    HIM
# 15949       Wicked Game  2012    HIM
# 15950   You Are The One  2014    HIM
# 15951    Your Sweet 666  2014    HIM
#
#                                                     text Genre1 Genre2  \
# 0      Take it easy with me, please  \nTouch me gentl...    Pop   Rock
# 1      I'll never know why I had to go  \nWhy I had t...    Pop   Rock
# 2      Making somebody happy is a question of give an...    Pop   Rock
# 3      Down in the street they're all singing and sho...    Pop   Rock
# 4      Chiquitita, tell me what's wrong  \nYou're enc...    Pop   Rock
# ...                                                  ...    ...    ...
# 15947  You can't escape the wrath of my heart  \nBeat...   Rock    Pop
# 15948  Leave all behind now to watch her crawl  \nThr...   Rock    Pop
# 15949  The world was on fire  \nNo one could save me ...   Rock    Pop
# 15950  No I won't surrender  \nAt any cost  \nYou're ...   Rock    Pop
# 15951  There are things you should know  \nThe distan...   Rock    Pop
#
#        number_of_tokens
# 0                  1434
# 1                  1477
# 2                  1263
# 3                  2028
# 4                  1591
# ...                 ...
# 15947               674
# 15948               901
# 15949              1384
# 15950               608
# 15951               921
#
# [15952 rows x 7 columns]

# %%
songs.to_csv("songtexte_bereinigt_gekuerzt")

# %% [markdown]
# #### sample data

# %%
songs_sample = songs.copy()
songs_sample = songs_sample.sample(frac=.25, replace=False, random_state=42)
songs_sample
# Out:
#                    artist                          song  \
# 20468           Van Halen        Take Your Whiskey Home
# 41605           Lil Wayne                     Army Gunz
# 52292       Stevie Wonder              Isn't She Lovely
# 42697        Mariah Carey                  O Holy Night
# 27993               Clash  I'm So Bored With The U.S.A.
# ...                   ...                           ...
# 25325      Billie Holiday                My Last Affair
# 28783  Dave Matthews Band             The Space Between
# 18645             Squeeze            Crying In My Sleep
# 32684        Foo Fighters                    Dear Lover
# 9201           Jason Mraz              Kickin' With You
#
#                                                     text  number_of_tokens
# 20468  [well, my, baby, she, don't, want, me, around....               224
# 41605  [yeah, yeah, yeah, (i, got, army, gunz), yeah,...               578
# 52292  [isn't, she, lovely, isn't, she, wonderful, is...               108
# 42697  [o, holy, night, the, stars, are, brightly, sh...                78
# 27993  [yankee, soldier, he, want, to, shoot, some, s...               113
# ...                                                  ...               ...
# 25325  [can't, you, see, what, love, and, romance, ha...                97
# 28783  [you, cannot, quit, me, so, quickly, is, no, h...               310
# 18645  [breaking, up, is, breaking, my, heart, is, sh...               178
# 32684  [dear, lover, do, you, remember?, the, sound, ...               134
# 9201   [ahhhh, oh, kickin', with, you, wooh, huh, yea...               311
#
# [12708 rows x 4 columns]

# %%
songs_sample.to_csv("sample_25percent.csv")

# %% [markdown]
# ### Stemming

# %%
songs = pd.read_csv("../songs_25.csv")
songs.head(2)
# Out:
#    Unnamed: 0 artists          song  \
# 0           0    ABBA      Me And I
# 1           1    ABBA  My Mama Said
#
#                                                 text  number_of_tokens Genre1  \
# 0  sometimes when i'm mad  there's a part of me t...              1551    Pop
# 1  tried to sneak out without saying  with my lou...              1029    Pop
#
#   Genre2  check                                                POS
# 0   Rock   True  mad little sad mean other rainy gloomy funny d...
# 1   Rock   True  record la la la la red la la la la dead la la ...

# %%
import spacy
import en_core_web_sm
from nltk.stem import PorterStemmer
from nltk.stem import SnowballStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

sentence = songs.text[0]

ps = PorterStemmer()

for i, row in songs.iterrows():
    words = word_tokenize(row.text)
    sent = ""
    for word in words:
        sent = sent + " " + ps.stem(word)
    songs.at[i,"stemmed_text"] = sent
songs
# Out:
#                    song  date artist  \
# 0      Andante, Andante  1980   ABBA
# 1        As Good As New  1979   ABBA
# 2      Bang-A-Boomerang  1975   ABBA
# 3             Cassandra  1981   ABBA
# 4            Chiquitita  1979   ABBA
# ...                 ...   ...    ...
# 15947     Vampire Heart  2005    HIM
# 15948        Venus Doom  2007    HIM
# 15949       Wicked Game  2012    HIM
# 15950   You Are The One  2014    HIM
# 15951    Your Sweet 666  2014    HIM
#
#                                                     text Genre1 Genre2  \
# 0      Take it easy with me, please  \nTouch me gentl...    Pop   Rock
# 1      I'll never know why I had to go  \nWhy I had t...    Pop   Rock
# 2      Making somebody happy is a question of give an...    Pop   Rock
# 3      Down in the street they're all singing and sho...    Pop   Rock
# 4      Chiquitita, tell me what's wrong  \nYou're enc...    Pop   Rock
# ...                                                  ...    ...    ...
# 15947  You can't escape the wrath of my heart  \nBeat...   Rock    Pop
# 15948  Leave all behind now to watch her crawl  \nThr...   Rock    Pop
# 15949  The world was on fire  \nNo one could save me ...   Rock    Pop
# 15950  No I won't surrender  \nAt any cost  \nYou're ...   Rock    Pop
# 15951  There are things you should know  \nThe distan...   Rock    Pop
#
#        number_of_tokens                                       stemmed_text
# 0                  1434   take it easi with me , pleas touch me gentli ...
# 1                  1477   I 'll never know whi I had to go whi I had to...
# 2                  1263   make somebodi happi is a question of give and...
# 3                  2028   down in the street they 're all sing and shou...
# 4                  1591   chiquitita , tell me what 's wrong you 're en...
# ...                 ...                                                ...
# 15947               674   you ca n't escap the wrath of my heart beat t...
# 15948               901   leav all behind now to watch her crawl throug...
# 15949              1384   the world wa on fire No one could save me but...
# 15950               608   No I wo n't surrend At ani cost you 're somet...
# 15951               921   there are thing you should know the distanc b...
#
# [15952 rows x 8 columns]

# %%
songs.drop("Unnamed: 0", axis=1, inplace=True)
# Out:
#      artists                song  \
# 0       ABBA            Me And I
# 1       ABBA        My Mama Said
# 2       ABBA   Hole In Your Soul
# 3       ABBA           Cassandra
# 4       ABBA       Just A Notion
# ...      ...                 ...
# 6795  ZZ Top            36-22-36
# 6796  ZZ Top     Deal Goin' Down
# 6797  ZZ Top  Can't Stop Rockin'
# 6798  ZZ Top   I Got The Message
# 6799  ZZ Top        Antenna Head
#
#                                                    text  number_of_tokens  \
# 0     sometimes when i'm mad  there's a part of me t...              1551
# 1     tried to sneak out without saying  with my lou...              1029
# 2     you feel bad  let me tell you  we all get the ...              1831
# 3     down in the street they're all singing and sho...              1964
# 4     just a notion that's all  just a feeling that ...               514
# ...                                                 ...               ...
# 6795  what  what  what you want? hey  my thing is a ...               646
# 6796  when the deal goin' down and you gonna take yo...               746
# 6797  i heard about the rock for sometime  i know.  ...               995
# 6798  i'm picking up on a signal  that's in the air ...               495
# 6799  old 61's my number on the hi-way  i'm turnin' ...               556
#
#      Genre1 Genre2  check                                                POS  \
# 0       Pop   Rock   True  mad little sad mean other rainy gloomy funny d...
# 1       Pop   Rock   True  record la la la la red la la la la dead la la ...
# 2       Pop   Rock   True  bad bad bad sad loose cool bright romantic bad...
# 3       Pop   Rock   True  alive dead hollow smart sorry last sorry final...
# 4       Pop   Rock   True  mistaking right wrong special notion feeling m...
# ...     ...    ...    ...                                                ...
# 6795   Rock    Pop   True  real fine real fine round thing thing thing th...
# 6796   Rock    Pop   True  deal chance mystery trance future deal deal no...
# 6797   Rock    Pop   True  easy wrong right low loose high rock roll rock...
# 6798   Rock    Pop   True  straight electric about empty straight straigh...
# 6799   Rock    Pop   True  bad only only red full number hi way v ass way...
#
#                                            stemmed_text
# 0      sometim when i 'm mad there 's a part of me t...
# 1      tri to sneak out without say with my loudest ...
# 2      you feel bad let me tell you we all get the b...
# 3      down in the street they 're all sing and shou...
# 4      just a notion that 's all just a feel that yo...
# ...                                                 ...
# 6795   what what what you want ? hey my thing is a r...
# 6796   when the deal goin ' down and you gon na take...
# 6797   i heard about the rock for sometim i know . i...
# 6798   i 'm pick up on a signal that 's in the air t...
# 6799   old 61 's my number on the hi-way i 'm turnin...
#
# [6800 rows x 9 columns]

# %%
songs.to_csv("songs_plus_dates.csv")
