# %% [markdown]
# ### Alternative Online-Implementierung, die inkrementelle Aktualisierungen der Positionen der Zentren mit Hilfe von Mini-Chargen durchführt. Für das Lernen in großem Maßstab (sagen wir n_samples > 10k) ist miniBatchKMeans wahrscheinlich viel schneller als die Standard-Implementierung.

# %%
# Import necessary libraries
from copy import deepcopy
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from matplotlib import pyplot as plt

# %matplotlib inline
from sklearn.cluster import KMeans 
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.preprocessing import normalize
from sklearn.metrics import pairwise_distances
import itertools
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from sklearn import manifold
import sklearn.datasets 
from sklearn.preprocessing import normalize

# %%
df = pd.read_csv("../songs_25.csv")

# %%
df.head(2)
# Out:
#    Unnamed: 0 artists          song  \
# 0           0    ABBA      Me And I
# 1           1    ABBA  My Mama Said
#
#                                                 text  number_of_tokens Genre1  \
# 0  sometimes when i'm mad  there's a part of me t...              1551    Pop
# 1  tried to sneak out without saying  with my lou...              1029    Pop
#
#   Genre2  check                                                POS  \
# 0   Rock   True  mad little sad mean other rainy gloomy funny d...
# 1   Rock   True  record la la la la red la la la la dead la la ...
#
#                                         stemmed_text
# 0   sometim when i 'm mad there 's a part of me t...
# 1   tri to sneak out without say with my loudest ...

# %% [markdown]
# ## Beispiel von Scikit-learn

# %%
from sklearn.cluster import MiniBatchKMeans
import numpy as np
X = np.array([[1, 2], [1, 4], [1, 0],
               [4, 2], [4, 0], [4, 4],
               [4, 5], [0, 1], [2, 2],
               [3, 2], [5, 5], [1, -1]])

# %%
 # manually fit on batches
kmeans = MiniBatchKMeans(n_clusters=2,
                          random_state=0,
                          batch_size=6)
kmeans = kmeans.partial_fit(X[0:6,:])
kmeans = kmeans.partial_fit(X[6:12,:])
kmeans.cluster_centers_
# Out:
# array([[1, 1],
#        [3, 4]])

# %%
kmeans.predict([[0, 0], [4, 4]])
# Out:
# array([0, 1])

# %%
# fit on the whole data
kmeans = MiniBatchKMeans(n_clusters=2,
                         random_state=0,
                         batch_size=6,
                         max_iter=10).fit(X)
kmeans.cluster_centers_
# Out:
# array([[3.95918367, 2.40816327],
#        [1.12195122, 1.3902439 ]])

# %%
kmeans.predict([[0, 0], [4, 4]])
# Out:
# array([1, 0])

# %% [markdown]
# ## MiniBatchKMeans auf unseren Datensatz angewendet mit PCA

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD


data = df['text']
tf_idf_vectorizor = TfidfVectorizer(
                             max_features = 20000)
tf_idf = tf_idf_vectorizor.fit_transform(data)
tf_idf_norm = normalize(tf_idf)
tf_idf_array = tf_idf_norm.toarray()
sklearn_pca = PCA(n_components = 3)
data= sklearn_pca.fit_transform(tf_idf_array)

# %%
from sklearn.cluster import MiniBatchKMeans

sklearn_pca = PCA(n_components = 2)
Y_sklearn = sklearn_pca.fit_transform(tf_idf_array)
kmeans = MiniBatchKMeans(n_clusters=10, random_state=0, batch_size=6)
fitted = kmeans.fit(Y_sklearn)
prediction = kmeans.predict(Y_sklearn)

# %%
plt.figure(figsize=(7,5))
plt.scatter(Y_sklearn[:, 0], Y_sklearn[:, 1], c=prediction, s=70, cmap='viridis')
plt.title('PCA')
plt.savefig('K_Means/PCA_Mini-Batch_Lyrics.png', bbox_inches = "tight")

# %% [markdown]
# ## MiniBatchKMeans auf unseren Datensatz angewendet mit t-SNE und Genre-Markern

# %%
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE

from sklearn.cluster import MiniBatchKMeans

# %%
data = TfidfVectorizer().fit_transform(df.POS.values.astype(str))

# %%
X_reduced = TruncatedSVD(n_components=10, random_state=0).fit_transform(data)

# %%
perplexity = [50]
for p in perplexity:
    X_embedded = TSNE(n_components=2, perplexity=p, n_iter=1000,learning_rate=10, verbose=2).fit_transform(X_reduced)
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 6800 samples in 0.009s...
# [t-SNE] Computed neighbors for 6800 samples in 0.988s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 6800
# [t-SNE] Computed conditional probabilities for sample 2000 / 6800
# [t-SNE] Computed conditional probabilities for sample 3000 / 6800
# [t-SNE] Computed conditional probabilities for sample 4000 / 6800
# [t-SNE] Computed conditional probabilities for sample 5000 / 6800
# [t-SNE] Computed conditional probabilities for sample 6000 / 6800
# [t-SNE] Computed conditional probabilities for sample 6800 / 6800
# [t-SNE] Mean sigma: 0.031116
# [t-SNE] Computed conditional probabilities in 0.684s
# [t-SNE] Iteration 50: error = 85.7520981, gradient norm = 0.0000004 (50 iterations in 2.134s)
# [t-SNE] Iteration 100: error = 85.7520752, gradient norm = 0.0000290 (50 iterations in 2.159s)
# [t-SNE] Iteration 150: error = 83.9829559, gradient norm = 0.0021407 (50 iterations in 3.300s)
# [t-SNE] Iteration 200: error = 82.4909058, gradient norm = 0.0006446 (50 iterations in 3.208s)
# [t-SNE] Iteration 250: error = 82.1160660, gradient norm = 0.0001344 (50 iterations in 2.040s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 82.116066
# [t-SNE] Iteration 300: error = 3.5359693, gradient norm = 0.0058529 (50 iterations in 1.802s)
# [t-SNE] Iteration 350: error = 2.9385495, gradient norm = 0.0027777 (50 iterations in 1.693s)
# [t-SNE] Iteration 400: error = 2.6282806, gradient norm = 0.0017921 (50 iterations in 1.643s)
# [t-SNE] Iteration 450: error = 2.4293587, gradient norm = 0.0012599 (50 iterations in 1.624s)
# [t-SNE] Iteration 500: error = 2.2942808, gradient norm = 0.0009497 (50 iterations in 1.609s)
# [t-SNE] Iteration 550: error = 2.1956215, gradient norm = 0.0007503 (50 iterations in 1.605s)
# [t-SNE] Iteration 600: error = 2.1206765, gradient norm = 0.0006135 (50 iterations in 1.587s)
# [t-SNE] Iteration 650: error = 2.0615547, gradient norm = 0.0005173 (50 iterations in 1.588s)
# [t-SNE] Iteration 700: error = 2.0134246, gradient norm = 0.0004388 (50 iterations in 1.585s)
# [t-SNE] Iteration 750: error = 1.9736878, gradient norm = 0.0003770 (50 iterations in 1.594s)
# [t-SNE] Iteration 800: error = 1.9402809, gradient norm = 0.0003307 (50 iterations in 1.592s)
# [t-SNE] Iteration 850: error = 1.9118893, gradient norm = 0.0002922 (50 iterations in 1.591s)
# [t-SNE] Iteration 900: error = 1.8874258, gradient norm = 0.0002633 (50 iterations in 1.593s)
# [t-SNE] Iteration 950: error = 1.8659800, gradient norm = 0.0002388 (50 iterations in 1.594s)
# [t-SNE] Iteration 1000: error = 1.8471591, gradient norm = 0.0002166 (50 iterations in 1.595s)
# [t-SNE] KL divergence after 1000 iterations: 1.847159

# %%
kmeans = MiniBatchKMeans(n_clusters=10, random_state=0, batch_size=6)
fitted = kmeans.fit(X_embedded)
prediction = kmeans.predict(X_embedded)

# %%
markers = ('o', 'v', '^', 's', 'p', '*','d', 'P', 'X')
plt.figure(figsize=(15,10))
sns.scatterplot(X_embedded[:, 0], X_embedded[:, 1],hue=prediction, style=df.Genre1, markers=markers, palette=sns.color_palette("hls", len(np.unique(prediction))))

plt.title('MiniBatch with POS')
plt.savefig('minibatch_kmeans_tsne_pos.png')
